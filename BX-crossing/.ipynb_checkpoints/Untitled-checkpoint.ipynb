# %%
import torch
import pickle

# %%
PATH='/home/kirana/Documents/phd/exp3_autoencoder'
DATAPATH='/home/kirana/Documents/final_dissertation_final/experiments/datasets/bookcrossing'

# %%
embed_cat=torch.load(f'{DATAPATH}/inter/save')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-816f2b75ae5d> in <module>
# ----> 1 embed_cat=torch.load(f'{DATAPATH}/inter/save')
#
# ~/anaconda3/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     385         f = f.open('rb')
#     386     try:
# --> 387         return _load(f, map_location, pickle_module, **pickle_load_args)
#     388     finally:
#     389         if new_fd:
#
# ~/anaconda3/lib/python3.7/site-packages/torch/serialization.py in _load(f, map_location, pickle_module, **pickle_load_args)
#     579     for key in deserialized_storage_keys:
#     580         assert key in deserialized_objects
# --> 581         deserialized_objects[key]._set_from_file(f, offset, f_should_read_directly)
#     582         offset = None
#     583
#
# RuntimeError: unexpected EOF, expected 8 more bytes. The file might be corrupted.

# %%
embed_cat
# Out:
# [tensor([[ 0.1153,  0.3208, -0.1078,  ..., -0.2167,  0.0388,  0.2969],
#          [ 0.1642,  0.2022,  0.0683,  ..., -0.1179,  1.3301,  1.5515],
#          [ 0.8645,  0.3890, -0.2696,  ...,  0.0000,  0.6350,  2.0225],
#          ...,
#          [ 0.4900, -0.2705,  0.6921,  ...,  0.3082,  0.4541, -1.1250],
#          [ 0.6512, -0.2141,  0.6010,  ..., -0.1124, -0.4912,  0.7047],
#          [-0.5154,  1.0701, -0.0215,  ..., -0.5124, -1.4318, -0.1087]],
#         device='cuda:1', requires_grad=True),
#  tensor([[-1.7680e-01, -3.1324e-01, -5.2745e-02,  ...,  2.6785e-01,
#           -1.1699e+00, -2.0678e-01],
#          [-3.6085e-01, -5.2789e-01,  0.0000e+00,  ...,  1.8047e-01,
#            1.2261e-01,  1.5264e-01],
#          [ 3.9582e-33,  7.0006e-38,  4.6242e-38,  ...,  6.2081e-38,
#           -4.3766e-38, -3.7634e-40],
#          ...,
#          [-3.6085e-01, -5.2789e-01,  1.5875e+00,  ...,  1.8047e-01,
#            1.2261e-01,  1.5264e-01],
#          [ 2.0543e-01,  1.9815e-01, -2.0437e-01,  ..., -1.9504e-01,
#           -4.7224e-06,  2.0709e-01],
#          [-8.9472e-02, -4.1751e-03,  8.3640e-02,  ...,  3.1982e-01,
#            6.3784e-01, -1.6797e-01]], device='cuda:1', requires_grad=True),
#  tensor([[ 0.0000,  0.5713,  1.3560,  ...,  0.4196,  0.1214,  1.4727],
#          [ 1.3099, -0.7773,  1.1705,  ...,  0.1131, -0.2469, -0.0655],
#          [ 0.8684,  1.1461,  1.4406,  ...,  0.3470, -0.1542,  0.5461],
#          ...,
#          [ 1.3099, -0.7773,  1.1705,  ...,  0.1131, -0.2469, -0.0655],
#          [ 0.0267,  1.0281, -0.1598,  ..., -0.5195, -1.9813, -0.5532],
#          [ 0.0000,  0.4479,  0.0000,  ..., -0.9670,  2.9127,  0.0202]],
#         device='cuda:1', requires_grad=True),
#  tensor([[ 0.2949,  0.5071,  0.2780,  ..., -0.4792,  0.1146, -0.1403],
#          [ 0.3464,  0.1240,  0.0000,  ..., -0.2251, -0.6743,  0.0000],
#          [-0.3869,  0.2632,  2.2452,  ..., -1.0008, -1.2127, -0.8948],
#          ...,
#          [ 0.3464,  0.1240, -0.3385,  ..., -0.2251, -0.6743,  0.3563],
#          [-0.3742,  0.7469, -1.8321,  ..., -0.8773,  0.5633,  0.5766],
#          [-0.3742,  0.7469, -1.8321,  ..., -0.8773,  0.5633,  0.5766]],
#         device='cuda:1', requires_grad=True)]

# %%
import pickle

# %%
[Xb,Yb,cat]=pickle.load(open(f'{DATAPATH}/inter/savepickle','rb'))

# %%
cat
# Out:
# [tensor([[ 0.0734,  0.5544, -0.7144,  ...,  0.7724, -1.7400,  0.1521],
#          [-0.2454,  0.6980, -0.1192,  ..., -0.5076,  0.0649,  0.5186],
#          [-0.4472,  0.4082,  0.0255,  ..., -0.2435, -0.1126, -1.0497],
#          ...,
#          [-1.4932, -0.3306,  1.0294,  ...,  0.7273,  0.2317,  0.1463],
#          [-1.3266,  1.3181,  0.7866,  ...,  0.7082,  0.7080,  0.7244],
#          [ 0.1996, -1.1800,  1.8188,  ..., -1.2505,  0.4312,  1.6152]],
#         device='cuda:1', requires_grad=True),
#  tensor([[ 2.0727e-01, -1.7181e-01,  9.5390e-02,  ..., -1.8019e-01,
#           -1.3222e-02,  1.7313e-01],
#          [-1.5159e-01,  1.7634e-01,  1.4021e-01,  ..., -1.9187e-01,
#           -1.9104e-01,  3.5715e-02],
#          [-8.7742e-01, -2.8026e-01,  1.1513e-01,  ...,  2.7013e-01,
#           -8.6541e-04,  9.8431e-01],
#          ...,
#          [-4.7534e-38,  4.0832e-38,  3.9684e-38,  ...,  2.5294e-38,
#           -2.2380e-38, -4.0507e-38],
#          [-1.5409e-01, -1.1428e-01,  3.5513e-02,  ...,  2.3826e-01,
#           -4.2778e-01,  1.6195e-03],
#          [-3.4983e-38, -5.3334e-38,  1.0725e-38,  ...,  3.4631e-38,
#           -6.2931e-38,  1.6892e-38]], device='cuda:1', requires_grad=True),
#  tensor([[-1.8138e-01,  5.7279e-02, -2.0862e-01,  ..., -2.1489e-01,
#           -2.4354e-01,  1.6732e-01],
#          [ 3.7280e-01, -9.9516e-02,  2.2120e+00,  ...,  4.6499e-01,
#            5.0718e-01,  1.3198e-02],
#          [-8.6064e-01, -6.6375e-01, -1.4857e-01,  ..., -7.1345e-01,
#            6.2160e-01,  1.1663e+00],
#          ...,
#          [-5.5108e-38, -1.1993e-38, -5.8487e-38,  ...,  6.0556e-38,
#            5.9664e-38, -6.7054e-38],
#          [-8.2745e-01,  3.4432e-01,  1.6500e+00,  ...,  5.4634e-01,
#            7.0765e-01, -3.9866e-02],
#          [ 1.0915e+00, -5.1664e-01,  4.2094e-01,  ..., -7.3041e-01,
#           -5.1307e-03, -1.7053e+00]], device='cuda:1', requires_grad=True),
#  tensor([[-0.2594,  0.2230, -0.1741,  ..., -0.1736, -0.2512,  0.2088],
#          [ 1.1354,  0.8449, -0.7142,  ...,  1.2755,  0.8157, -0.8207],
#          [ 0.7731, -0.5107,  0.4191,  ..., -0.0819,  0.6285, -0.8251],
#          ...,
#          [-0.1348,  0.3305, -0.4347,  ...,  1.7880, -0.5098, -0.3069],
#          [ 0.5947, -0.4182,  0.4370,  ..., -0.6242,  0.3400, -0.2027],
#          [-0.9003,  0.2980,  0.9261,  ..., -1.1996,  0.1338,  0.1380]],
#         device='cuda:1', requires_grad=True)]

# %%
Xb
# Out:
# tensor([[5.6350e+03, 9.1550e+04, 1.5691e+00,  ..., 6.9645e+04, 3.4457e+04,
#          7.1230e+03],
#         [3.1920e+04, 1.4818e+05, 1.5691e+00,  ..., 1.0976e+05, 7.2600e+02,
#          1.5000e+01],
#         [1.0991e+04, 1.5132e+05, 1.5691e+00,  ..., 1.2810e+03, 4.3900e+02,
#          1.0000e+01],
#         ...,
#         [8.9500e+02, 1.8179e+05, 1.5691e+00,  ..., 1.3272e+05, 6.0973e+04,
#          1.9300e+03],
#         [1.1639e+04, 5.0740e+03, 1.5691e+00,  ..., 4.3380e+03, 2.4980e+03,
#          7.5000e+01],
#         [5.1935e+04, 1.8135e+05, 1.5694e+00,  ..., 1.2864e+05, 1.3020e+03,
#          2.7600e+02]], device='cuda:1')

# %%
Xb.sum(1)
# Out:
# tensor([209103.0469, 292772.0312, 169018.0469,  18694.7148, 257268.0469,
#          74506.0469,  32338.0391,  26790.0391, 158175.0469, 234212.7500,
#         306678.7188,  43426.0391, 450212.0312, 301694.0312,  49056.0391,
#         160358.0469, 107370.0391, 364163.3750,   6679.5293, 126033.0312,
#          22559.0391, 240976.8594, 218273.0469, 209430.0469,  86859.7578,
#           3010.0420, 189629.0312, 248205.7031, 402390.8750,  89310.0469,
#         261190.0469,   3613.0420,  30313.0391, 120296.7188,  55337.0391,
#          99015.0391, 382867.0312, 111939.0547,  49478.0391,  35698.0391,
#         186406.1094, 106272.0391,  51671.0391, 243577.0469, 188304.0312,
#          19187.0391, 205703.0625,  81026.8125,  10276.8740,  63844.9062,
#         186122.0469,  88411.0547,  18047.0410, 310587.0312,  12834.0420,
#           5643.0415, 107315.7422, 128834.0469, 178755.7031, 116093.0547,
#         179437.0469, 379013.9062,  24645.0391, 363744.0312], device='cuda:1')

# %%
Yb
# Out:
# tensor([[ 5.],
#         [ 6.],
#         [ 4.],
#         [ 7.],
#         [ 8.],
#         [10.],
#         [ 9.],
#         [ 5.],
#         [ 9.],
#         [10.],
#         [ 6.],
#         [10.],
#         [ 3.],
#         [ 8.],
#         [ 7.],
#         [ 9.],
#         [ 7.],
#         [ 8.],
#         [ 8.],
#         [ 9.],
#         [ 8.],
#         [ 9.],
#         [ 5.],
#         [ 6.],
#         [10.],
#         [ 8.],
#         [ 8.],
#         [ 8.],
#         [ 5.],
#         [ 7.],
#         [ 6.],
#         [10.],
#         [ 8.],
#         [ 9.],
#         [ 8.],
#         [ 8.],
#         [10.],
#         [ 1.],
#         [10.],
#         [10.],
#         [ 8.],
#         [ 9.],
#         [ 3.],
#         [ 8.],
#         [ 5.],
#         [ 8.],
#         [10.],
#         [ 8.],
#         [ 1.],
#         [ 6.],
#         [ 6.],
#         [ 7.],
#         [ 9.],
#         [ 9.],
#         [ 1.],
#         [ 8.],
#         [ 7.],
#         [10.],
#         [ 6.],
#         [ 9.],
#         [ 8.],
#         [10.],
#         [ 5.],
#         [ 7.]], device='cuda:1')

# %%
cat
# Out:
# [tensor([[ 0.0734,  0.5544, -0.7144,  ...,  0.7724, -1.7400,  0.1521],
#          [-0.2454,  0.6980, -0.1192,  ..., -0.5076,  0.0649,  0.5186],
#          [-0.4472,  0.4082,  0.0255,  ..., -0.2435, -0.1126, -1.0497],
#          ...,
#          [-1.4932, -0.3306,  1.0294,  ...,  0.7273,  0.2317,  0.1463],
#          [-1.3266,  1.3181,  0.7866,  ...,  0.7082,  0.7080,  0.7244],
#          [ 0.1996, -1.1800,  1.8188,  ..., -1.2505,  0.4312,  1.6152]],
#         device='cuda:1', requires_grad=True),
#  tensor([[ 2.0727e-01, -1.7181e-01,  9.5390e-02,  ..., -1.8019e-01,
#           -1.3222e-02,  1.7313e-01],
#          [-1.5159e-01,  1.7634e-01,  1.4021e-01,  ..., -1.9187e-01,
#           -1.9104e-01,  3.5715e-02],
#          [-8.7742e-01, -2.8026e-01,  1.1513e-01,  ...,  2.7013e-01,
#           -8.6541e-04,  9.8431e-01],
#          ...,
#          [-4.7534e-38,  4.0832e-38,  3.9684e-38,  ...,  2.5294e-38,
#           -2.2380e-38, -4.0507e-38],
#          [-1.5409e-01, -1.1428e-01,  3.5513e-02,  ...,  2.3826e-01,
#           -4.2778e-01,  1.6195e-03],
#          [-3.4983e-38, -5.3334e-38,  1.0725e-38,  ...,  3.4631e-38,
#           -6.2931e-38,  1.6892e-38]], device='cuda:1', requires_grad=True),
#  tensor([[-1.8138e-01,  5.7279e-02, -2.0862e-01,  ..., -2.1489e-01,
#           -2.4354e-01,  1.6732e-01],
#          [ 3.7280e-01, -9.9516e-02,  2.2120e+00,  ...,  4.6499e-01,
#            5.0718e-01,  1.3198e-02],
#          [-8.6064e-01, -6.6375e-01, -1.4857e-01,  ..., -7.1345e-01,
#            6.2160e-01,  1.1663e+00],
#          ...,
#          [-5.5108e-38, -1.1993e-38, -5.8487e-38,  ...,  6.0556e-38,
#            5.9664e-38, -6.7054e-38],
#          [-8.2745e-01,  3.4432e-01,  1.6500e+00,  ...,  5.4634e-01,
#            7.0765e-01, -3.9866e-02],
#          [ 1.0915e+00, -5.1664e-01,  4.2094e-01,  ..., -7.3041e-01,
#           -5.1307e-03, -1.7053e+00]], device='cuda:1', requires_grad=True),
#  tensor([[-0.2594,  0.2230, -0.1741,  ..., -0.1736, -0.2512,  0.2088],
#          [ 1.1354,  0.8449, -0.7142,  ...,  1.2755,  0.8157, -0.8207],
#          [ 0.7731, -0.5107,  0.4191,  ..., -0.0819,  0.6285, -0.8251],
#          ...,
#          [-0.1348,  0.3305, -0.4347,  ...,  1.7880, -0.5098, -0.3069],
#          [ 0.5947, -0.4182,  0.4370,  ..., -0.6242,  0.3400, -0.2027],
#          [-0.9003,  0.2980,  0.9261,  ..., -1.1996,  0.1338,  0.1380]],
#         device='cuda:1', requires_grad=True)]
