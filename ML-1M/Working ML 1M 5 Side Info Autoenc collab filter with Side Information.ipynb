# %%
PATH='/home/kirana/Documents/phd/exp3_autoencoder'
DATAPATH='/home/kirana/Documents/final_dissertation_final/experiments/datasets/ml-1m'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import os
import pickle
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn

# %%
[df, df_train,df_valid,df,df_ratings,idx_to_user,\
             idx_to_movie,movie_to_idx,user_to_idx]=pickle.load(open(f'{DATAPATH}/reads.pkl','rb'))

# %%
df.shape
# Out:
# (1000209, 20)

# %%
df.head().T
# Out:
#                                                     648724  \
# userId                                                3908
# itemId                                                2347
# rating                                                   4
# timestamp                                        965941231
# gender                                                   M
# age                                                     25
# occupation                                               0
# zip                                                  10021
# title                Pope of Greenwich Village, The (1984)
# genre                                               Action
# random_dstype                                        train
# user_idx                                                 1
# item_idx                                                 1
# dstype_random_train                                      1
# dstype_random_valid                                      0
# gender_idx                                               1
# age_idx                                                  1
# title_idx                                                1
# genre_idx                                                1
# zip_idx                                                  1
#
#                                       203881  \
# userId                                  1254
# itemId                                  1541
# rating                                     2
# timestamp                          974823280
# gender                                     F
# age                                       18
# occupation                                 1
# zip                                    02144
# title                Addicted to Love (1997)
# genre                         Comedy|Romance
# random_dstype                          train
# user_idx                                   2
# item_idx                                   2
# dstype_random_train                        1
# dstype_random_valid                        0
# gender_idx                                 2
# age_idx                                    2
# title_idx                                  2
# genre_idx                                  2
# zip_idx                                    2
#
#                                                243394  \
# userId                                           1467
# itemId                                           2617
# rating                                              3
# timestamp                                   977173059
# gender                                              M
# age                                                25
# occupation                                          5
# zip                                             97007
# title                               Mummy, The (1999)
# genre                Action|Adventure|Horror|Thriller
# random_dstype                                   train
# user_idx                                            3
# item_idx                                            3
# dstype_random_train                                 1
# dstype_random_valid                                 0
# gender_idx                                          1
# age_idx                                             1
# title_idx                                           3
# genre_idx                                           3
# zip_idx                                             3
#
#                                                              788507  \
# userId                                                         4717
# itemId                                                         3754
# rating                                                            3
# timestamp                                                 963502544
# gender                                                            M
# age                                                              45
# occupation                                                       17
# zip                                                           48310
# title                Adventures of Rocky and Bullwinkle, The (2000)
# genre                                   Animation|Children's|Comedy
# random_dstype                                                 train
# user_idx                                                          4
# item_idx                                                          4
# dstype_random_train                                               1
# dstype_random_valid                                               0
# gender_idx                                                        1
# age_idx                                                           3
# title_idx                                                         4
# genre_idx                                                         4
# zip_idx                                                           4
#
#                                           301066
# userId                                      1789
# itemId                                      2997
# rating                                         5
# timestamp                              974700402
# gender                                         M
# age                                            1
# occupation                                    10
# zip                                        19116
# title                Being John Malkovich (1999)
# genre                                     Comedy
# random_dstype                              train
# user_idx                                       5
# item_idx                                       5
# dstype_random_train                            1
# dstype_random_valid                            0
# gender_idx                                     1
# age_idx                                        4
# title_idx                                      5
# genre_idx                                      5
# zip_idx                                        5

# %%
occupation_to_idx={j:i+1 for i,j in enumerate(df['occupation'].unique())}
age_to_idx={j:i+1 for i,j in enumerate(df['age'].unique())}
gender_to_idx={j:i+1 for i,j in enumerate(df['gender'].unique())}

# %%
df['gender_idx']=[gender_to_idx.get(i) for i in df['gender']]
df['age_idx']=[age_to_idx.get(i) for i in df['age']]
df['occupation_idx']=[occupation_to_idx.get(i) for i in df['occupation']]

# %%
df['gender_idx'].value_counts()
# Out:
# 1    753769
# 2    246440
# Name: gender_idx, dtype: int64

# %%
df['occupation_idx'].value_counts()
# Out:
# 8     131032
# 1     130499
# 12    105425
# 2      85351
# 4      72816
# 7      60397
# 15     57214
# 6      50068
# 11     49109
# 10     46021
# 18     37205
# 14     31623
# 5      23290
# 16     22951
# 3      21850
# 13     20563
# 9      14904
# 20     13754
# 17     12086
# 19     11345
# 21      2706
# Name: occupation_idx, dtype: int64

# %%
df['genre_idx'].value_counts()
# Out:
# 5      116883
# 14     111423
# 2       42712
# 16      42245
# 25      29170
# 53      26759
# 38      22563
# 58      18248
# 70      17851
# 69      17783
# 28      14656
# 22      14309
# 36      13970
# 1       12311
# 23      12224
# 13      11870
# 11      11069
# 6       10446
# 77      10382
# 60       9681
# 47       9311
# 61       9077
# 75       8851
# 7        8649
# 65       8220
# 32       7946
# 4        7870
# 72       7467
# 73       7438
# 86       6809
#         ...
# 254       182
# 274       168
# 252       168
# 237       162
# 266       160
# 245       144
# 268       135
# 276       130
# 267       130
# 278       102
# 282        98
# 230        85
# 293        77
# 291        68
# 281        67
# 296        65
# 283        63
# 292        62
# 284        55
# 298        44
# 299        44
# 277        43
# 295        41
# 280        41
# 294        30
# 297        29
# 285        27
# 279         5
# 300         2
# 301         1
# Name: genre_idx, Length: 301, dtype: int64

# %%
df_train=df.loc[df['random_dstype']=='train']
df_valid=df.loc[df['random_dstype']!='train']

# %%
df_train.head().T
# Out:
#                                                     648724  \
# userId                                                3908
# itemId                                                2347
# rating                                                   4
# timestamp                                        965941231
# gender                                                   M
# age                                                     25
# occupation                                               0
# zip                                                  10021
# title                Pope of Greenwich Village, The (1984)
# genre                                               Action
# random_dstype                                        train
# user_idx                                                 1
# item_idx                                                 1
# dstype_random_train                                      1
# dstype_random_valid                                      0
# gender_idx                                               1
# age_idx                                                  1
# title_idx                                                1
# genre_idx                                                1
# zip_idx                                                  1
# occupation_idx                                           1
#
#                                       203881  \
# userId                                  1254
# itemId                                  1541
# rating                                     2
# timestamp                          974823280
# gender                                     F
# age                                       18
# occupation                                 1
# zip                                    02144
# title                Addicted to Love (1997)
# genre                         Comedy|Romance
# random_dstype                          train
# user_idx                                   2
# item_idx                                   2
# dstype_random_train                        1
# dstype_random_valid                        0
# gender_idx                                 2
# age_idx                                    2
# title_idx                                  2
# genre_idx                                  2
# zip_idx                                    2
# occupation_idx                             2
#
#                                                243394  \
# userId                                           1467
# itemId                                           2617
# rating                                              3
# timestamp                                   977173059
# gender                                              M
# age                                                25
# occupation                                          5
# zip                                             97007
# title                               Mummy, The (1999)
# genre                Action|Adventure|Horror|Thriller
# random_dstype                                   train
# user_idx                                            3
# item_idx                                            3
# dstype_random_train                                 1
# dstype_random_valid                                 0
# gender_idx                                          1
# age_idx                                             1
# title_idx                                           3
# genre_idx                                           3
# zip_idx                                             3
# occupation_idx                                      3
#
#                                                              788507  \
# userId                                                         4717
# itemId                                                         3754
# rating                                                            3
# timestamp                                                 963502544
# gender                                                            M
# age                                                              45
# occupation                                                       17
# zip                                                           48310
# title                Adventures of Rocky and Bullwinkle, The (2000)
# genre                                   Animation|Children's|Comedy
# random_dstype                                                 train
# user_idx                                                          4
# item_idx                                                          4
# dstype_random_train                                               1
# dstype_random_valid                                               0
# gender_idx                                                        1
# age_idx                                                           3
# title_idx                                                         4
# genre_idx                                                         4
# zip_idx                                                           4
# occupation_idx                                                    4
#
#                                           301066
# userId                                      1789
# itemId                                      2997
# rating                                         5
# timestamp                              974700402
# gender                                         M
# age                                            1
# occupation                                    10
# zip                                        19116
# title                Being John Malkovich (1999)
# genre                                     Comedy
# random_dstype                              train
# user_idx                                       5
# item_idx                                       5
# dstype_random_train                            1
# dstype_random_valid                            0
# gender_idx                                     1
# age_idx                                        4
# title_idx                                      5
# genre_idx                                      5
# zip_idx                                        5
# occupation_idx                                 5

# %%
df_train.shape,df_valid.shape
# Out:
# ((900188, 21), (100021, 21))

# %% [markdown]
# ### Add the autoencoder features

# %%
import pickle

# %%
[df_train_user_autoenc,df_valid_user_autoenc,user_mtx_1_weights,user_mtx_2_weights,df_train_user_autoenc_linear,df_valid_user_autoenc_linear]=\
    pickle.load(open(f'{DATAPATH}/inter/user_autoenc_weights.pkl','rb'))

# %%
[df_train_item_autoenc, df_valid_item_autoenc,item_mtx_1_weights,item_mtx_2_weights,df_train_item_autoenc_linear, df_valid_item_autoenc_linear]=\
    pickle.load(open(f'{DATAPATH}/inter/item_autoenc_weights.pkl','rb'))

# %%
df_train_user_autoenc.shape, type(df_train_user_autoenc),df_train_user_autoenc.head()
# Out:
# ((6041, 11),
#  pandas.core.frame.DataFrame,
#     user_idx  user_autoenc0  user_autoenc1  user_autoenc2  user_autoenc3  \
#  0         0      -0.918095       2.296391       0.263371      -0.011968
#  1         1      -1.694891      -0.151930       1.124974      -1.841133
#  2         2       0.807896      -1.376931       0.162299       0.080092
#  3         3      -0.736317      -0.517018       1.213105      -1.961564
#  4         4      -1.399151       0.328619      -1.665964      -1.062431
#
#     user_autoenc4  user_autoenc5  user_autoenc6  user_autoenc7  user_autoenc8  \
#  0      -0.804040      -0.389131       0.454120      -3.545166       2.439914
#  1      -2.112378      -1.080319       1.374260      -2.909504      -0.340611
#  2       0.537038       0.585960      -0.161436       1.048445      -1.035838
#  3      -1.423592      -1.065770       0.938449      -1.570770      -0.542528
#  4      -0.760788       0.939962      -1.311538      -0.389501       0.414060
#
#     user_autoenc9
#  0       1.331096
#  1      -1.397754
#  2      -0.490745
#  3      -1.756809
#  4      -0.095679  )

# %%
df_valid_user_autoenc.shape, type(df_valid_user_autoenc),df_valid_user_autoenc.head()
# Out:
# ((6041, 11),
#  pandas.core.frame.DataFrame,
#     user_idx  user_autoenc0  user_autoenc1  user_autoenc2  user_autoenc3  \
#  0         0      -0.710982       0.897209      -0.313327      -0.537236
#  1         1      -0.635214       0.002973       1.403316      -1.286969
#  2         2      -1.781903       0.222397      -0.553926      -1.723093
#  3         3      -0.822826      -1.370865       0.959654      -1.831420
#  4         4      -1.122299       0.172465      -0.530118      -0.993004
#
#     user_autoenc4  user_autoenc5  user_autoenc6  user_autoenc7  user_autoenc8  \
#  0      -0.207326       1.817019      -0.083455      -1.915403       1.017241
#  1      -1.220138      -0.331535       1.213825      -2.250492       0.138666
#  2      -1.125409       1.774892      -0.177812      -1.222502       0.203632
#  3      -0.930850       0.896978       1.000327      -0.871036      -1.322870
#  4      -0.511379       1.123822      -0.379063      -1.483297       0.429764
#
#     user_autoenc9
#  0       0.319337
#  1      -0.798446
#  2      -0.765520
#  3      -1.950774
#  4      -0.169135  )

# %%
df_train_item_autoenc.shape, type(df_train_item_autoenc),df_train_item_autoenc.head()
# Out:
# ((3707, 26),
#  pandas.core.frame.DataFrame,
#     item_idx  item_autoenc0  item_autoenc1  item_autoenc2  item_autoenc3  \
#  0         0      -4.290696       1.535837      -2.863299       2.215095
#  1         1      -3.186090       1.619871      -4.623875       1.611612
#  2         2      -0.421671      -1.740489       0.700414       1.222373
#  3         3      -3.646142       4.019207      -4.617493       3.038867
#  4         4      -0.253813       1.821706      -0.079822       5.658348
#
#     item_autoenc4  item_autoenc5  item_autoenc6  item_autoenc7  item_autoenc8  \
#  0       2.391089       1.921405       3.355848       4.209718       1.995065
#  1       6.894719       2.890666       3.657045       3.941945       4.006826
#  2       5.434728       2.580276      -0.305813       4.300034       2.113038
#  3       5.001753       5.424593       5.720086       4.584945       4.141813
#  4      -4.511702      -1.919843      -0.854778      -1.483453      -8.076346
#
#     ...  item_autoenc15  item_autoenc16  item_autoenc17  item_autoenc18  \
#  0  ...        0.164515       -0.839483       -2.070024        2.311688
#  1  ...        3.218517        2.546161       -0.447566        3.715678
#  2  ...       -2.053917        1.027072       -0.588286        0.455141
#  3  ...        3.855402        2.923810       -0.008642        5.089916
#  4  ...       -2.535455       -3.821946       -4.017133       -1.795143
#
#     item_autoenc19  item_autoenc20  item_autoenc21  item_autoenc22  \
#  0        2.054844       -2.968903        0.464862       -2.342608
#  1        0.373989       -4.584003        2.359148       -3.566233
#  2       -0.415664       -1.453486        5.357845        0.752502
#  3        4.330089       -3.420625        2.169323       -2.206610
#  4       -0.851271        4.189686       -4.017469        0.367825
#
#     item_autoenc23  item_autoenc24
#  0       -3.434470        0.482895
#  1       -6.401432       -1.908490
#  2       -3.572295       -4.163743
#  3       -3.330783       -0.628950
#  4        4.764617        0.370236
#
#  [5 rows x 26 columns])

# %%
df_valid_item_autoenc.shape, type(df_valid_item_autoenc),df_valid_item_autoenc.head()
# Out:
# ((3707, 26),
#  pandas.core.frame.DataFrame,
#     item_idx  item_autoenc0  item_autoenc1  item_autoenc2  item_autoenc3  \
#  0         0      -2.640463       3.512858      -1.048760       4.423928
#  1         1      -2.424724       3.152336      -4.673349       2.324574
#  2         2       0.887352      -1.248138       1.220102       0.455281
#  3         3      -0.468162       5.248226      -4.684432       1.671049
#  4         4       1.164515       2.161365      -0.585891       3.572651
#
#     item_autoenc4  item_autoenc5  item_autoenc6  item_autoenc7  item_autoenc8  \
#  0       0.499727       1.970455       3.788411       2.612572      -4.432913
#  1       3.759815       2.444036       3.341689       2.484791       1.931070
#  2       6.160451       2.679912       0.353989       2.368717       2.061396
#  3       2.287045       3.212496       3.388133       1.611730      -0.349124
#  4      -2.329178      -0.847237      -0.582573      -0.493120      -5.531364
#
#     ...  item_autoenc15  item_autoenc16  item_autoenc17  item_autoenc18  \
#  0  ...        0.620732       -0.098825       -3.881708        1.625305
#  1  ...        1.783592        1.711640       -0.173657        2.507289
#  2  ...       -0.524468        0.742765       -0.730791        0.361537
#  3  ...        3.622572        2.200349       -0.847715        2.927625
#  4  ...       -0.906221       -1.528127       -2.664351       -1.480901
#
#     item_autoenc19  item_autoenc20  item_autoenc21  item_autoenc22  \
#  0        1.716548        0.332960       -1.638975       -1.478018
#  1        1.696394       -3.091375        1.136294       -2.488652
#  2       -0.970675       -1.416442        5.243442        1.519626
#  3        1.642136       -1.400116       -1.504510       -0.421831
#  4        0.362256        1.551230       -2.249399        0.630900
#
#     item_autoenc23  item_autoenc24
#  0        0.776653        0.819198
#  1       -3.819597       -0.243545
#  2       -5.025009       -3.916132
#  3       -1.527694       -3.814773
#  4        1.230392       -0.230206
#
#  [5 rows x 26 columns])

# %%
df_valid_user_autoenc.isnull().any()
# Out:
# user_idx         False
# user_autoenc0    False
# user_autoenc1    False
# user_autoenc2    False
# user_autoenc3    False
# user_autoenc4    False
# user_autoenc5    False
# user_autoenc6    False
# user_autoenc7    False
# user_autoenc8    False
# user_autoenc9    False
# dtype: bool

# %%
df_valid.isnull().sum()
# Out:
# userId                 0
# itemId                 0
# rating                 0
# timestamp              0
# gender                 0
# age                    0
# occupation             0
# zip                    0
# title                  0
# genre                  0
# random_dstype          0
# user_idx               0
# item_idx               0
# dstype_random_train    0
# dstype_random_valid    0
# gender_idx             0
# age_idx                0
# title_idx              0
# genre_idx              0
# zip_idx                0
# occupation_idx         0
# dtype: int64

# %%
df_train.isnull().sum()
# Out:
# userId                 0
# itemId                 0
# rating                 0
# timestamp              0
# gender                 0
# age                    0
# occupation             0
# zip                    0
# title                  0
# genre                  0
# random_dstype          0
# user_idx               0
# item_idx               0
# dstype_random_train    0
# dstype_random_valid    0
# gender_idx             0
# age_idx                0
# title_idx              0
# genre_idx              0
# zip_idx                0
# occupation_idx         0
# dtype: int64

# %%
df_train.shape, df_valid.shape
# Out:
# ((900188, 21), (100021, 21))

# %%
df_train.dtypes
# Out:
# userId                  int64
# itemId                  int64
# rating                  int64
# timestamp               int64
# gender                 object
# age                     int64
# occupation              int64
# zip                    object
# title                  object
# genre                  object
# random_dstype          object
# user_idx                int64
# item_idx                int64
# dstype_random_train     int64
# dstype_random_valid     int64
# gender_idx              int64
# age_idx                 int64
# title_idx               int64
# genre_idx               int64
# zip_idx                 int64
# occupation_idx          int64
# dtype: object

# %%
df_train.head()
# Out:
#         userId  itemId  rating  timestamp gender  age  occupation    zip  \
# 648724    3908    2347       4  965941231      M   25           0  10021
# 203881    1254    1541       2  974823280      F   18           1  02144
# 243394    1467    2617       3  977173059      M   25           5  97007
# 788507    4717    3754       3  963502544      M   45          17  48310
# 301066    1789    2997       5  974700402      M    1          10  19116
#
#                                                  title  \
# 648724           Pope of Greenwich Village, The (1984)
# 203881                         Addicted to Love (1997)
# 243394                               Mummy, The (1999)
# 788507  Adventures of Rocky and Bullwinkle, The (2000)
# 301066                     Being John Malkovich (1999)
#
#                                    genre  ... user_idx  item_idx  \
# 648724                            Action  ...        1         1
# 203881                    Comedy|Romance  ...        2         2
# 243394  Action|Adventure|Horror|Thriller  ...        3         3
# 788507       Animation|Children's|Comedy  ...        4         4
# 301066                            Comedy  ...        5         5
#
#         dstype_random_train  dstype_random_valid  gender_idx  age_idx  \
# 648724                    1                    0           1        1
# 203881                    1                    0           2        2
# 243394                    1                    0           1        1
# 788507                    1                    0           1        3
# 301066                    1                    0           1        4
#
#         title_idx  genre_idx  zip_idx  occupation_idx
# 648724          1          1        1               1
# 203881          2          2        2               2
# 243394          3          3        3               3
# 788507          4          4        4               4
# 301066          5          5        5               5
#
# [5 rows x 21 columns]

# %%
df_train=pd.merge(df_train,df_train_item_autoenc,on='item_idx',how='left')

# %%
df_train.shape
# Out:
# (900188, 46)

# %%
print(df_valid.shape)
df_valid=pd.merge(df_valid,df_valid_item_autoenc,on='item_idx',how='left')
df_valid.shape
# Out:
# (100021, 21)
# (100021, 46)

# %%
df_valid.shape
# Out:
# (100021, 46)

# %%
print(df_valid.shape)
df_valid=pd.merge(df_valid,df_valid_user_autoenc,on='user_idx',how='left')
df_valid.shape
# Out:
# (100021, 46)
# (100021, 56)

# %%
print(df_train.shape)
df_train=pd.merge(df_train,df_train_user_autoenc,on='user_idx',how='left')
df_train.shape
# Out:
# (900188, 46)
# (900188, 56)

# %%
df_train.columns
# Out:
# Index(['userId', 'itemId', 'rating', 'timestamp', 'gender', 'age',
#        'occupation', 'zip', 'title', 'genre', 'random_dstype', 'user_idx',
#        'item_idx', 'dstype_random_train', 'dstype_random_valid', 'gender_idx',
#        'age_idx', 'title_idx', 'genre_idx', 'zip_idx', 'occupation_idx',
#        'item_autoenc0', 'item_autoenc1', 'item_autoenc2', 'item_autoenc3',
#        'item_autoenc4', 'item_autoenc5', 'item_autoenc6', 'item_autoenc7',
#        'item_autoenc8', 'item_autoenc9', 'item_autoenc10', 'item_autoenc11',
#        'item_autoenc12', 'item_autoenc13', 'item_autoenc14', 'item_autoenc15',
#        'item_autoenc16', 'item_autoenc17', 'item_autoenc18', 'item_autoenc19',
#        'item_autoenc20', 'item_autoenc21', 'item_autoenc22', 'item_autoenc23',
#        'item_autoenc24', 'user_autoenc0', 'user_autoenc1', 'user_autoenc2',
#        'user_autoenc3', 'user_autoenc4', 'user_autoenc5', 'user_autoenc6',
#        'user_autoenc7', 'user_autoenc8', 'user_autoenc9'],
#       dtype='object')

# %%
autoenc_cols=df_train.columns[df_train.columns.str.contains('autoenc')]

# %%
autoenc_cols=autoenc_cols.tolist()

# %%
autoenc_cols
# Out:
# ['item_autoenc0',
#  'item_autoenc1',
#  'item_autoenc2',
#  'item_autoenc3',
#  'item_autoenc4',
#  'item_autoenc5',
#  'item_autoenc6',
#  'item_autoenc7',
#  'item_autoenc8',
#  'item_autoenc9',
#  'item_autoenc10',
#  'item_autoenc11',
#  'item_autoenc12',
#  'item_autoenc13',
#  'item_autoenc14',
#  'item_autoenc15',
#  'item_autoenc16',
#  'item_autoenc17',
#  'item_autoenc18',
#  'item_autoenc19',
#  'item_autoenc20',
#  'item_autoenc21',
#  'item_autoenc22',
#  'item_autoenc23',
#  'item_autoenc24',
#  'user_autoenc0',
#  'user_autoenc1',
#  'user_autoenc2',
#  'user_autoenc3',
#  'user_autoenc4',
#  'user_autoenc5',
#  'user_autoenc6',
#  'user_autoenc7',
#  'user_autoenc8',
#  'user_autoenc9']

# %%
df_train.head()
# Out:
#    userId  itemId  rating  timestamp gender  age  occupation    zip  \
# 0    3908    2347       4  965941231      M   25           0  10021
# 1    1254    1541       2  974823280      F   18           1  02144
# 2    1467    2617       3  977173059      M   25           5  97007
# 3    4717    3754       3  963502544      M   45          17  48310
# 4    1789    2997       5  974700402      M    1          10  19116
#
#                                             title  \
# 0           Pope of Greenwich Village, The (1984)
# 1                         Addicted to Love (1997)
# 2                               Mummy, The (1999)
# 3  Adventures of Rocky and Bullwinkle, The (2000)
# 4                     Being John Malkovich (1999)
#
#                               genre  ... user_autoenc0  user_autoenc1  \
# 0                            Action  ...     -1.694891      -0.151930
# 1                    Comedy|Romance  ...      0.807896      -1.376931
# 2  Action|Adventure|Horror|Thriller  ...     -0.736317      -0.517018
# 3       Animation|Children's|Comedy  ...     -1.399151       0.328619
# 4                            Comedy  ...      0.432887      -0.056065
#
#    user_autoenc2  user_autoenc3  user_autoenc4  user_autoenc5  user_autoenc6  \
# 0       1.124974      -1.841133      -2.112378      -1.080319       1.374260
# 1       0.162299       0.080092       0.537038       0.585960      -0.161436
# 2       1.213105      -1.961564      -1.423592      -1.065770       0.938449
# 3      -1.665964      -1.062431      -0.760788       0.939962      -1.311538
# 4       0.165773       0.295746       0.357427       0.560581       0.050682
#
#    user_autoenc7  user_autoenc8  user_autoenc9
# 0      -2.909504      -0.340611      -1.397754
# 1       1.048445      -1.035838      -0.490745
# 2      -1.570770      -0.542528      -1.756809
# 3      -0.389501       0.414060      -0.095679
# 4      -1.070020       0.197620       0.240095
#
# [5 rows x 56 columns]

# %%
df_train[['user_idx','item_idx']+autoenc_cols].head()
# Out:
#    user_idx  item_idx  item_autoenc0  item_autoenc1  item_autoenc2  \
# 0         1         1      -3.186090       1.619871      -4.623875
# 1         2         2      -0.421671      -1.740489       0.700414
# 2         3         3      -3.646142       4.019207      -4.617493
# 3         4         4      -0.253813       1.821706      -0.079822
# 4         5         5       1.271805      -1.232789       2.155728
#
#    item_autoenc3  item_autoenc4  item_autoenc5  item_autoenc6  item_autoenc7  \
# 0       1.611612       6.894719       2.890666       3.657045       3.941945
# 1       1.222373       5.434728       2.580276      -0.305813       4.300034
# 2       3.038867       5.001753       5.424593       5.720086       4.584945
# 3       5.658348      -4.511702      -1.919843      -0.854778      -1.483453
# 4       0.708601       2.945284       0.331645      -1.821778       1.437376
#
#    ...  user_autoenc0  user_autoenc1  user_autoenc2  user_autoenc3  \
# 0  ...      -1.694891      -0.151930       1.124974      -1.841133
# 1  ...       0.807896      -1.376931       0.162299       0.080092
# 2  ...      -0.736317      -0.517018       1.213105      -1.961564
# 3  ...      -1.399151       0.328619      -1.665964      -1.062431
# 4  ...       0.432887      -0.056065       0.165773       0.295746
#
#    user_autoenc4  user_autoenc5  user_autoenc6  user_autoenc7  user_autoenc8  \
# 0      -2.112378      -1.080319       1.374260      -2.909504      -0.340611
# 1       0.537038       0.585960      -0.161436       1.048445      -1.035838
# 2      -1.423592      -1.065770       0.938449      -1.570770      -0.542528
# 3      -0.760788       0.939962      -1.311538      -0.389501       0.414060
# 4       0.357427       0.560581       0.050682      -1.070020       0.197620
#
#    user_autoenc9
# 0      -1.397754
# 1      -0.490745
# 2      -1.756809
# 3      -0.095679
# 4       0.240095
#
# [5 rows x 37 columns]

# %%
df_valid['rating'].describe(),df_train['rating'].describe()
# Out:
# (count    100021.000000
#  mean          3.584587
#  std           1.114938
#  min           1.000000
#  25%           3.000000
#  50%           4.000000
#  75%           4.000000
#  max           5.000000
#  Name: rating, dtype: float64, count    900188.000000
#  mean          3.581229
#  std           1.117342
#  min           1.000000
#  25%           3.000000
#  50%           4.000000
#  75%           4.000000
#  max           5.000000
#  Name: rating, dtype: float64)

# %%
df_train.columns
# Out:
# Index(['userId', 'itemId', 'rating', 'timestamp', 'gender', 'age',
#        'occupation', 'zip', 'title', 'genre', 'random_dstype', 'user_idx',
#        'item_idx', 'dstype_random_train', 'dstype_random_valid', 'gender_idx',
#        'age_idx', 'title_idx', 'genre_idx', 'zip_idx', 'occupation_idx',
#        'item_autoenc0', 'item_autoenc1', 'item_autoenc2', 'item_autoenc3',
#        'item_autoenc4', 'item_autoenc5', 'item_autoenc6', 'item_autoenc7',
#        'item_autoenc8', 'item_autoenc9', 'item_autoenc10', 'item_autoenc11',
#        'item_autoenc12', 'item_autoenc13', 'item_autoenc14', 'item_autoenc15',
#        'item_autoenc16', 'item_autoenc17', 'item_autoenc18', 'item_autoenc19',
#        'item_autoenc20', 'item_autoenc21', 'item_autoenc22', 'item_autoenc23',
#        'item_autoenc24', 'user_autoenc0', 'user_autoenc1', 'user_autoenc2',
#        'user_autoenc3', 'user_autoenc4', 'user_autoenc5', 'user_autoenc6',
#        'user_autoenc7', 'user_autoenc8', 'user_autoenc9'],
#       dtype='object')

# %%
emb_cols=['gender_idx','title_idx','genre_idx','zip_idx', 'occupation_idx', 'age_idx']

# %%
[(col, df_train[col].nunique()) for col in emb_cols]
# Out:
# [('gender_idx', 2),
#  ('title_idx', 3692),
#  ('genre_idx', 301),
#  ('zip_idx', 3439),
#  ('occupation_idx', 21),
#  ('age_idx', 7)]

# %%
[(df_train[col].nunique(), min(50,df_train[col].nunique()//2)) for col in emb_cols]
# Out:
# [(2, 1), (3692, 50), (301, 50), (3439, 50), (21, 10), (7, 3)]

# %%
emb_szs=[(df[col].nunique(), min(50,df[col].nunique()//2)) for col in emb_cols]

# %%
emb_cols
# Out:
# ['gender_idx',
#  'title_idx',
#  'genre_idx',
#  'zip_idx',
#  'occupation_idx',
#  'age_idx']

# %% [markdown]
# ### Dataset and DataLoader

# %%
class cfdata (torch.utils.data.dataset.Dataset):
    def __init__(self,dfX,dfY,denseCols):
        self.dfX,self.dfY=dfX,dfY
        self.denseCols=denseCols
        
    def __len__ (self):
        return self.dfX.shape[0]
    
    def __getitem__ (self, idx):
        return torch.FloatTensor(self.dfX.iloc[idx].values),torch.FloatTensor([self.dfY.values[idx]])

# %%
dstrain=cfdata(df_train[['user_idx','item_idx']+autoenc_cols+emb_cols],df_train['rating'],autoenc_cols)
dsvalid=cfdata(df_valid[['user_idx','item_idx']+autoenc_cols+emb_cols],df_valid['rating'],autoenc_cols)

# %%
df_train.shape
# Out:
# (900188, 56)

# %%
bs=256

# %%
dltrain=DataLoader(dstrain,bs,True)

# %%
dlvalid=DataLoader(dsvalid,bs,True)

# %%
610/10, 9724/25
# Out:
# (61.0, 388.96)

# %%
len(user_to_idx),len(movie_to_idx)
# Out:
# (6040, 3706)

# %%
emb_szs
# Out:
# [(2, 1), (3706, 50), (301, 50), (3439, 50), (21, 10), (7, 3)]

# %%
emb_szs[0][0],emb_szs[1][1]
# Out:
# (2, 50)

# %%
[nn.Embedding(x[0],x[1]) for x in emb_szs][0]
# Out:
# Embedding(2, 1)

# %% [markdown]
# ## Model Architecture

# %%
n_users=len(user_to_idx)
n_movies=len(movie_to_idx)
n_emb_user=50
n_emb_movie=50
min_rating=min(df_train['rating'])
max_rating=max(df_train['rating'])
dropout_e=0.1
hidden=[25,15,10,10]
dropouts=[0.2,0.2,0.2]

# %%
def hidden_layer(x,y,dropout,activation=nn.Sigmoid()):
    return nn.Sequential(
        nn.Linear(x, y),
        activation,
        nn.Dropout(p=dropout)
        )

# %%
pretrain_wts=None

# %%
pretrain_wts=pickle.load(open(f'{DATAPATH}/wts_embs','rb'))

# %%
emb_cols
# Out:
# ['gender_idx',
#  'title_idx',
#  'genre_idx',
#  'zip_idx',
#  'occupation_idx',
#  'age_idx']

# %%
df_train[emb_cols].describe(), df_valid[emb_cols].describe()
# Out:
# (          gender_idx      title_idx      genre_idx        zip_idx  \
#  count  900188.000000  900188.000000  900188.000000  900188.000000
#  mean        1.246389     938.144097      58.016682    1015.492488
#  std         0.430908     739.934040      61.946342     794.922210
#  min         1.000000       1.000000       1.000000       1.000000
#  25%         1.000000     343.000000      14.000000     362.000000
#  50%         1.000000     749.000000      36.000000     833.000000
#  75%         1.000000    1395.000000      80.000000    1497.000000
#  max         2.000000    3692.000000     301.000000    3439.000000
#
#         occupation_idx        age_idx
#  count   900188.000000  900188.000000
#  mean         8.299853       2.950054
#  std          5.320746       2.118832
#  min          1.000000       1.000000
#  25%          4.000000       1.000000
#  50%          8.000000       2.000000
#  75%         12.000000       5.000000
#  max         21.000000       7.000000  ,
#            gender_idx      title_idx      genre_idx        zip_idx  \
#  count  100021.000000  100021.000000  100021.000000  100021.000000
#  mean        1.246388     945.120605      57.847802    1017.023435
#  std         0.430909     740.875545      61.617070     797.453399
#  min         1.000000       1.000000       1.000000       1.000000
#  25%         1.000000     349.000000      14.000000     366.000000
#  50%         1.000000     754.000000      36.000000     831.000000
#  75%         1.000000    1409.000000      79.000000    1497.000000
#  max         2.000000    3706.000000     299.000000    3439.000000
#
#         occupation_idx        age_idx
#  count   100021.000000  100021.000000
#  mean         8.320303       2.946341
#  std          5.324499       2.122430
#  min          1.000000       1.000000
#  25%          4.000000       1.000000
#  50%          8.000000       2.000000
#  75%         12.000000       5.000000
#  max         21.000000       7.000000  )

# %%
emb_szs
# Out:
# [(2, 1), (3706, 50), (301, 50), (3439, 50), (21, 10), (7, 3)]

# %%
class cf(nn.Module):    
    def __init__(self,n_users,n_emb_user,n_emb_item,n_items,min_rating,max_rating,autoenc_cols,pretrain_wts,\
                 emb_cols, emb_szs, dropout_e=0.01,hidden=[15,5],dropouts=[0.2,0.2],error_type="mse"):
        super().__init__()
        self.n_users,self.n_emb_user,self.n_emb_item,self.n_items,self.min_rating,self.max_rating=\
                    n_users,n_emb_user,n_emb_item,n_items,min_rating,max_rating
        self.dropout_e,self.hidden,self.dropouts=dropout_e,hidden,dropouts
        self.autoenc_cols,self.len_dense_cols=autoenc_cols,len(autoenc_cols)
        self.emb_cols, self.emb_szs=emb_cols,emb_szs
        self.create_architecture()
        
        if pretrain_wts is not None:
            self.emb_user.weight.data=torch.FloatTensor(pretrain_wts[0])
            self.emb_item.weight.data=torch.FloatTensor(pretrain_wts[1])
            self.ub.weight.data=torch.FloatTensor(pretrain_wts[2])
            self.ib.weight.data=torch.FloatTensor(pretrain_wts[3])

        if error_type!="mse":
            self.criterion=nn.L1Loss()
        else:
            self.criterion=nn.MSELoss()
        
    def create_architecture(self):
        self.emb_user=nn.Embedding(self.n_users+1,self.n_emb_user)
        self.emb_item=nn.Embedding(self.n_items+1,self.n_emb_item)
        self.ub=nn.Embedding(self.n_users+1,1)
        self.ib=nn.Embedding(self.n_items+1,1)
        self.emb_cats=nn.ModuleList([nn.Embedding(x[0]+1,x[1]) for x in self.emb_szs])
        
        self.emb_dropout=nn.Dropout(self.dropout_e)

        
        self.lin1= nn.Sequential(nn.Linear(self.n_emb_user+self.n_emb_item,self.hidden[0]),
                    nn.ReLU(),
                    nn.Dropout(p=dropouts[0]) )
        self.lin_bias=nn.Linear(3,2)
        
        self.lin_cats=nn.Sequential(nn.Linear(sum([x[1] for x in self.emb_szs]),self.hidden[3]),
                                    nn.ReLU(),
                                    nn.Dropout(p=dropouts[2]))
        
        self.lin2= nn.Sequential (nn.Linear(self.len_dense_cols,self.hidden[1]),
                    #nn.ReLU(),
                    nn.Dropout(p=dropouts[1]) )
        self.lin3= nn.Sequential (nn.Linear(self.hidden[0]+self.hidden[1]+self.hidden[3]+2,self.hidden[2]),
                    nn.ReLU(),
                    nn.Dropout(p=dropouts[2]))
        self.lin4=nn.Linear(self.hidden[2],1)
        self.sigmoid=nn.Sigmoid()
        
        
    def init_parameters(self):
        nn.init.kaiming_normal_(self.emb_user.weight.data)
        nn.init.kaiming_normal_(self.emb_item.weight.data)
        #nn.init.kaiming_normal_(lin)
       
    def forward (self,Xb,Yb):

        users=Xb[:,0].long()
        items=Xb[:,1].long()
        users=self.emb_dropout(self.emb_user(users))
        items=self.emb_dropout(self.emb_item(items))
        users_bias=self.emb_dropout(self.ub(Xb[:,0].long()))
        items_bias=self.emb_dropout(self.ib(Xb[:,1].long()))
        embed=torch.cat([users,items],1)
        out1=self.lin1(embed)
        bias=torch.cat([users_bias,items_bias,users_bias+items_bias],1)
        biased=self.lin_bias(bias)
           
        denses=Xb[:,2:(2+self.len_dense_cols)]
        cats=Xb[:,(2+self.len_dense_cols):]

     
        #import pdb
        #pdb.set_trace()
        embed_cats=[self.emb_dropout(self.emb_cats[i](cats[:,i].long())) for i in range(len(self.emb_cols))] 
            
            
        cats=torch.cat(embed_cats,1)
        cats=self.lin_cats(cats)
        
        out2=self.lin2(denses)
        
        out3=torch.cat([out1,out2,cats,biased],1)
        
        out4=self.lin3(out3)
        
        out5=self.lin4(out4)
        
        out=self.sigmoid(out5)
        
        preds=out*(self.max_rating-self.min_rating)+self.min_rating
        #preds=preds.view(-1)
        loss=self.criterion(preds,Yb)
        return preds,loss

# %%
cfobj=cf(n_users,n_emb_user,n_emb_movie,n_movies,min_rating,max_rating,autoenc_cols,pretrain_wts,emb_cols,emb_szs,dropout_e,hidden,dropouts,error_type="mse")

# %%
cfobj
# Out:
# cf(
#   (emb_user): Embedding(6041, 50)
#   (emb_item): Embedding(3707, 50)
#   (ub): Embedding(6041, 1)
#   (ib): Embedding(3707, 1)
#   (emb_cats): ModuleList(
#     (0): Embedding(3, 1)
#     (1): Embedding(3707, 50)
#     (2): Embedding(302, 50)
#     (3): Embedding(3440, 50)
#     (4): Embedding(22, 10)
#     (5): Embedding(8, 3)
#   )
#   (emb_dropout): Dropout(p=0.1)
#   (lin1): Sequential(
#     (0): Linear(in_features=100, out_features=25, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2)
#   )
#   (lin_bias): Linear(in_features=3, out_features=2, bias=True)
#   (lin_cats): Sequential(
#     (0): Linear(in_features=164, out_features=10, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2)
#   )
#   (lin2): Sequential(
#     (0): Linear(in_features=35, out_features=15, bias=True)
#     (1): Dropout(p=0.2)
#   )
#   (lin3): Sequential(
#     (0): Linear(in_features=52, out_features=10, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2)
#   )
#   (lin4): Linear(in_features=10, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (criterion): MSELoss()
# )

# %%
for Xb, Yb in dltrain:
    break

# %%
cfobj.forward(Xb,Yb)
# Out:
# (tensor([[3.2018],
#          [3.1117],
#          [3.4627],
#          [2.9643],
#          [3.6547],
#          [3.1460],
#          [3.1183],
#          [2.8585],
#          [3.2632],
#          [3.0070],
#          [2.9703],
#          [2.9874],
#          [3.5899],
#          [2.7203],
#          [3.1039],
#          [3.4130],
#          [3.4533],
#          [2.8178],
#          [3.1065],
#          [3.1329],
#          [3.3807],
#          [3.3509],
#          [3.0639],
#          [2.9187],
#          [3.1532],
#          [2.8135],
#          [3.1491],
#          [3.4441],
#          [3.1653],
#          [2.9567],
#          [3.1814],
#          [3.2505],
#          [3.0279],
#          [3.4056],
#          [3.2144],
#          [3.4592],
#          [3.6864],
#          [3.0853],
#          [2.9497],
#          [3.4040],
#          [3.3775],
#          [3.2656],
#          [3.1613],
#          [2.9473],
#          [3.4630],
#          [3.2859],
#          [3.3194],
#          [3.1660],
#          [3.0627],
#          [3.0803],
#          [3.2277],
#          [3.1042],
#          [3.5173],
#          [3.2308],
#          [2.9500],
#          [3.1312],
#          [3.1482],
#          [3.1648],
#          [2.9933],
#          [3.0478],
#          [3.2908],
#          [3.4834],
#          [3.1196],
#          [2.8862],
#          [3.2456],
#          [3.1546],
#          [3.4177],
#          [3.1861],
#          [2.8148],
#          [2.9048],
#          [3.1287],
#          [3.1827],
#          [3.2536],
#          [3.3369],
#          [3.2591],
#          [3.3854],
#          [3.2462],
#          [3.0319],
#          [2.9348],
#          [3.1065],
#          [3.2150],
#          [2.8970],
#          [3.4868],
#          [3.1815],
#          [3.4810],
#          [3.3184],
#          [2.9358],
#          [2.9804],
#          [3.1543],
#          [3.5071],
#          [3.0033],
#          [3.0157],
#          [3.5132],
#          [3.2207],
#          [3.2125],
#          [3.2099],
#          [3.2284],
#          [3.1849],
#          [3.2681],
#          [3.3127],
#          [3.2808],
#          [3.4409],
#          [2.9886],
#          [3.0425],
#          [2.9662],
#          [3.0941],
#          [3.6052],
#          [2.7458],
#          [3.4420],
#          [3.1753],
#          [2.7896],
#          [3.4107],
#          [2.9060],
#          [3.3555],
#          [3.3170],
#          [3.4481],
#          [3.3047],
#          [2.7757],
#          [3.2039],
#          [3.2555],
#          [3.2365],
#          [3.2850],
#          [3.2479],
#          [3.2323],
#          [3.0226],
#          [3.2338],
#          [2.9384],
#          [2.9594],
#          [3.1436],
#          [3.2794],
#          [3.4090],
#          [3.4432],
#          [3.0645],
#          [3.4704],
#          [3.1601],
#          [2.9094],
#          [3.1505],
#          [2.9717],
#          [3.1183],
#          [3.2094],
#          [3.5509],
#          [3.3648],
#          [3.3636],
#          [3.2325],
#          [3.2519],
#          [3.1968],
#          [2.9840],
#          [3.3026],
#          [3.2355],
#          [3.1430],
#          [3.1787],
#          [3.1450],
#          [3.2723],
#          [3.2405],
#          [2.8900],
#          [3.0183],
#          [3.2430],
#          [3.1570],
#          [3.5153],
#          [3.4846],
#          [3.3673],
#          [3.0053],
#          [2.9717],
#          [3.2731],
#          [3.4447],
#          [3.0759],
#          [3.1975],
#          [3.5035],
#          [3.6240],
#          [3.0321],
#          [3.2674],
#          [3.1303],
#          [3.1537],
#          [3.2555],
#          [3.6787],
#          [3.0593],
#          [3.2956],
#          [3.1347],
#          [2.6037],
#          [3.2391],
#          [2.6933],
#          [3.1956],
#          [3.0694],
#          [3.3999],
#          [3.1184],
#          [3.0648],
#          [3.5647],
#          [3.1119],
#          [3.3224],
#          [3.3453],
#          [3.1274],
#          [3.1711],
#          [3.0629],
#          [2.7920],
#          [3.2028],
#          [3.3311],
#          [2.9160],
#          [2.7584],
#          [3.2763],
#          [3.1844],
#          [3.0605],
#          [3.0855],
#          [3.3614],
#          [3.0800],
#          [3.2949],
#          [3.0960],
#          [3.2991],
#          [3.1767],
#          [3.0990],
#          [2.8100],
#          [3.3872],
#          [3.2663],
#          [3.2141],
#          [3.3954],
#          [3.2287],
#          [2.8969],
#          [3.3259],
#          [3.2765],
#          [3.1399],
#          [3.2495],
#          [3.1820],
#          [3.1117],
#          [3.0972],
#          [3.1996],
#          [3.4623],
#          [2.8777],
#          [3.4876],
#          [3.3792],
#          [3.5690],
#          [3.0329],
#          [3.2405],
#          [3.4482],
#          [2.9685],
#          [2.8772],
#          [3.2130],
#          [3.4733],
#          [2.8078],
#          [3.1224],
#          [3.4578],
#          [3.4452],
#          [3.2980],
#          [3.1191],
#          [3.2812],
#          [2.8056],
#          [3.2837],
#          [3.6861],
#          [3.3811],
#          [2.9893],
#          [3.3500],
#          [3.1737],
#          [3.3776],
#          [3.3372],
#          [3.3156],
#          [3.4650],
#          [2.9269],
#          [3.3312]], grad_fn=<AddBackward0>),
#  tensor(1.4633, grad_fn=<MseLossBackward>))

# %% [markdown]
# ## Learner

# %%
device='cuda:1'

# %%
class Learner():
    def __init__(self,model,optimizer,metric_fn,device,bptt=12,print_every=5,clip_val=None,\
                 cycle_mult=0,lr_decay=0.7,wd_mult=6,start_lr=2e-2, end_lr=5e-4,error_type="mse"):
        self.model,self.optimizer,self.metric_fn,self.device,self.print_every,self.bptt,self.losses,self.clip_val=\
            model,optimizer,metric_fn,device,print_every,bptt,[],clip_val
        self.n_epochs=1
        self.cycle_mult,self.lr_decay=cycle_mult,lr_decay
        self.wd_mult=wd_mult
        for param_group in self.optimizer.param_groups:
            self.start_lr=param_group['lr']
            self.start_wd=param_group['weight_decay']
        self.wd=self.start_wd
        self.lr=self.start_lr
        self.end_lr=end_lr
        self.n_epoch=0
        self.lrs=[1e-2,5e-3,1e-4,5e-4]
        self.preds,self.preds_valid,self.trainY,self.actual=[],[],[],[]
        self.ratio=self.end_lr/self.start_lr
        self.num_steps=self.cycle_mult
        self.reset_cycle=self.cycle_mult
        self.error_type=error_type
        
    def fit (self,Xb,Yb,mode_train=True):
        if mode_train:
            self.model.train()
        else:
            self.model.eval()
        
        #import pdb
        #pdb.set_trace()
        preds,loss=self.model(Xb,Yb)

     
        if mode_train:
            if 1==0:
                lr =self.lrs[torch.randint(0,4,(1,))]
                for param_group in self.optimizer.param_groups:
                    param_group['lr']=lr
            
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()
        myloss=loss.item()
    
        
        with torch.no_grad():
            if self.error_type == "mse":
                acc=nn.L1Loss() (preds,Yb)
                myrmse=np.sqrt(myloss)
            else:
                acc=nn.MSELoss() (preds,Yb)
                myrmse=np.sqrt(acc.item())
            acc=acc.item()
                 
   
        del preds
        del loss
        
        if self.clip_val is not None:
            torch.nn.utils.clip_grad_norm_(self.model.parameters(), self.clip_val)
        
        return myloss, acc, myrmse
    
    def lr_find (self,start_lr,end_lr,iterator,n_batch):
        losses,lrs=[],[]
        ratio=end_lr/start_lr
        num_steps=n_batch
        lr=start_lr
        for i in range(num_steps):            
            lr=lr*(end_lr/start_lr)**(1/num_steps)
            lrs.append(lr)
        self.lrs=lrs
        self.run_epoch(iterator,mode_train=True,lrs=lrs)
    
    def run_epoch(self,iterator,mode_train,lrs=None):
        epoch_loss,epoch_acc,i,k=0,0,0,0
        epoch_rmse=0


        for Xb,Yb in iterator:
            Xb=Xb.to(self.device)
            Yb=Yb.to(self.device)
            
            if lrs is not None:
                lr=lrs[k]
                for param_group in self.optimizer.param_groups:
                    param_group['lr']=lr 
            

            loss,acc,myrmse=self.fit(Xb,Yb,mode_train)
            
            if lrs is not None:
                self.losses.append(loss)


            

            epoch_loss+=loss
            epoch_acc+=acc
            epoch_rmse+=myrmse
            
            k=k+1
            if k%self.print_every == 0:
                if k:
                    print (f'Batch:{k} {epoch_loss/(k)}  ')  
                    torch.cuda.empty_cache()

        epoch_loss=epoch_loss/len(iterator)
        epoch_acc=epoch_acc/len(iterator)
        epoch_rmse=epoch_rmse/len(iterator)
            
        return epoch_loss,epoch_acc,epoch_rmse
    
    def plot_lrs(self, n_roll=1,ylim=None,xlim=None):
        import seaborn as sns
        ax=sns.lineplot(x=self.lrs,y=pd.Series(self.losses).rolling(n_roll).mean())
        ax.set_xscale('log')
        ax.set_ylabel('Loss')
        ax.set_xlabel('Learning Rate')
        if ylim is not None:
            plt.ylim(ylim)
        if xlim is not None:
            plt.xlim(xlim)

     
    def run_epochs(self,dltrain,dlvalid,n_epochs=1):              
        for epoch in range(n_epochs):                
            loss,acc,rmse=self.run_epoch(dltrain,True)

            lossv,accv,rmsev=self.run_epoch(dlvalid,mode_train=False)
           
            if self.error_type=="mse":
                loss_mse=loss
                loss_rmse=rmse
                loss_mae=acc
                lossv_mse=lossv
                lossv_rmse=rmsev
                lossv_mae=accv
                
            else:
                loss_mse=acc
                loss_rmse=rmse
                loss_mae=loss
                lossv_mse=accv
                lossv_rmse=rmsev
                lossv_mae=lossv
            
            print (f'Epoch:{epoch} Learning rate {self.lr} Weight Decay {self.wd} Train Loss:{loss} \
                Valid Loss:{lossv} Train RMSE:{loss_rmse} Valid RMSE:{lossv_rmse} Train MSE:{loss_mse} Valid MSE:{lossv_mse} \
                Train MAE:{loss_mae} Valid MAE:{lossv_mae}')

              
         
     
            if self.cycle_mult:
                if self.n_epoch==self.reset_cycle:
                    self.lr=self.start_lr
                    #self.wd=self.start_wd
                    self.reset_cycle*=self.cycle_mult
                    #reset_cycle=self.n_epoch+reset_cycle
                    self.n_epoch=0
                    self.ratio=self.end_lr/self.start_lr
                    self.num_steps=self.reset_cycle
                else:
                    #self.lr*=(self.lr_decay**self.n_epoch)  
                    #if self.n_epoch>1:
                    #    self.wd*=self.wd_mult
                    self.lr=self.lr*(self.end_lr/self.start_lr)**(1/self.num_steps)
                    self.n_epoch+=1
        

                
            for param_group in self.optimizer.param_groups:
                param_group['lr']=self.lr
                #param_group['weight_decay']=self.wd

# %%
del cfobj

# %%
cfobj=cf(n_users,n_emb_user,n_emb_movie,n_movies,min_rating,max_rating,autoenc_cols,pretrain_wts,emb_cols,emb_szs,dropout_e,hidden,dropouts,error_type="mse")

# %%
cfobj=cfobj.to(device)

# %%
cfobj
# Out:
# cf(
#   (emb_user): Embedding(6041, 50)
#   (emb_item): Embedding(3707, 50)
#   (ub): Embedding(6041, 1)
#   (ib): Embedding(3707, 1)
#   (emb_cats): ModuleList(
#     (0): Embedding(3, 1)
#     (1): Embedding(3707, 50)
#     (2): Embedding(302, 50)
#     (3): Embedding(3440, 50)
#     (4): Embedding(22, 10)
#     (5): Embedding(8, 3)
#   )
#   (emb_dropout): Dropout(p=0.1)
#   (lin1): Sequential(
#     (0): Linear(in_features=100, out_features=25, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2)
#   )
#   (lin_bias): Linear(in_features=3, out_features=2, bias=True)
#   (lin_cats): Sequential(
#     (0): Linear(in_features=164, out_features=10, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2)
#   )
#   (lin2): Sequential(
#     (0): Linear(in_features=35, out_features=15, bias=True)
#     (1): Dropout(p=0.2)
#   )
#   (lin3): Sequential(
#     (0): Linear(in_features=52, out_features=10, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2)
#   )
#   (lin4): Linear(in_features=10, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (criterion): MSELoss()
# )

# %%
len(dltrain)
# Out:
# 3517

# %%
dltrain.batch_size
# Out:
# 256

# %%
wd=1e-7
optimizer=torch.optim.Adam(cfobj.parameters(),lr=7e-3,betas=(0.9,0.999), weight_decay=wd)

# %%
learner=Learner(cfobj,optimizer,None,device,0,8000,0.25,cycle_mult=0,error_type="mse")

# %%
learner.lr_find(1e-4,1e-1,dltrain,len(dltrain))

# %%
learner.plot_lrs(50), min(learner.losses)
# Out:
# (None, 0.6127890348434448)

# %%
learner.plot_lrs(10)

# %%
learner.plot_lrs(1)

# %%
del cfobj
torch.cuda.empty_cache()

# %%
cfobj=cf(n_users,n_emb_user,n_emb_movie,n_movies,min_rating,max_rating,autoenc_cols,pretrain_wts,emb_cols,emb_szs,dropout_e,hidden,dropouts,error_type="mse")
cfobj=cfobj.to(device)

# %%
wd=1e-7

# %%
optimizer=torch.optim.Adam(cfobj.parameters(),lr=5e-4,betas=(0.9,0.999), weight_decay=wd)
learner=Learner(cfobj,optimizer,None,device,0,12000,0.25,cycle_mult=0)

# %%
learner.run_epochs(dltrain,dlvalid,2)
# Out:
# Epoch:0 Learning rate 0.0005 Weight Decay 1e-07 Train Loss:0.8337827464345846                 Valid Loss:0.7528275955668495 Train RMSE:0.9110450817952955 Valid RMSE:0.8665966265218004 Train MSE:0.8337827464345846 Valid MSE:0.7528275955668495                 Train MAE:0.7252012161765209 Valid MAE:0.682578539299538
# Epoch:1 Learning rate 0.0005 Weight Decay 1e-07 Train Loss:0.7613088704999414                 Valid Loss:0.7356327040421079 Train RMSE:0.871553458702998 Valid RMSE:0.8567966638617642 Train MSE:0.7613088704999414 Valid MSE:0.7356327040421079                 Train MAE:0.6905266771033165 Valid MAE:0.6769416803289252

# %%
learner.run_epochs(dltrain,dlvalid,2)
# Out:
# Epoch:0 Learning rate 0.0005 Weight Decay 1e-07 Train Loss:0.7423455413766703                 Valid Loss:0.7282423809971041 Train RMSE:0.8605994580075764 Valid RMSE:0.8523049266013552 Train MSE:0.7423455413766703 Valid MSE:0.7282423809971041                 Train MAE:0.6805607310438279 Valid MAE:0.6716942759730932
# Epoch:1 Learning rate 0.0005 Weight Decay 1e-07 Train Loss:0.7329460925123114                 Valid Loss:0.7258021253758989 Train RMSE:0.8551120576166081 Valid RMSE:0.8509842243252211 Train MSE:0.7329460925123114 Valid MSE:0.7258021253758989                 Train MAE:0.6755904290091086 Valid MAE:0.6708729622309165

# %%
learner.run_epochs(dltrain,dlvalid,1)
# Out:
# Epoch:0 Learning rate 0.0005 Weight Decay 1e-07 Train Loss:0.7248533711807613                 Valid Loss:0.7257970749874554 Train RMSE:0.850400191681775 Valid RMSE:0.8509110968397782 Train MSE:0.7248533711807613 Valid MSE:0.7257970749874554                 Train MAE:0.6716420806738881 Valid MAE:0.6696021096480776

# %%
learner.run_epochs(dltrain,dlvalid,1)
# Out:
# Epoch:0 Learning rate 0.0005 Weight Decay 1e-07 Train Loss:0.7195724342860449                 Valid Loss:0.7252473965325319 Train RMSE:0.8472879684977818 Valid RMSE:0.8505203491005933 Train MSE:0.7195724342860449 Valid MSE:0.7252473965325319                 Train MAE:0.6689170804218979 Valid MAE:0.6704503973121838

# %%
optimizer=torch.optim.Adam(cfobj.parameters(),lr=1e-4,betas=(0.9,0.999), weight_decay=wd)
learner=Learner(cfobj,optimizer,None,device,0,12000,0.25,cycle_mult=2,start_lr=5e-4,end_lr=1e-5)
learner.run_epochs(dltrain,dlvalid,15)
# Out:
# Epoch:0 Learning rate 0.0001 Weight Decay 1e-07 Train Loss:0.7047014624888768                 Valid Loss:0.723385346667541 Train RMSE:0.8384366367271294 Valid RMSE:0.8494886584480237 Train MSE:0.7047014624888768 Valid MSE:0.723385346667541                 Train MAE:0.6612840904781416 Valid MAE:0.6671828543743514
# Epoch:1 Learning rate 3.1622776601683795e-05 Weight Decay 1e-07 Train Loss:0.7012026749502572                 Valid Loss:0.7231038054236976 Train RMSE:0.8363485397998054 Valid RMSE:0.8493354999859737 Train MSE:0.7012026749502572 Valid MSE:0.7231038054236976                 Train MAE:0.6593456493204956 Valid MAE:0.666522357927259
# Epoch:2 Learning rate 1e-05 Weight Decay 1e-07 Train Loss:0.6997293382078061                 Valid Loss:0.7228536337537839 Train RMSE:0.8354945080423667 Valid RMSE:0.8492346125779745 Train MSE:0.6997293382078061 Valid MSE:0.7228536337537839                 Train MAE:0.6585339109498328 Valid MAE:0.6666619414868562
# Epoch:3 Learning rate 0.0001 Weight Decay 1e-07 Train Loss:0.7012330312467211                 Valid Loss:0.7223232844296623 Train RMSE:0.8363941215725648 Valid RMSE:0.8489680923018329 Train MSE:0.7012330312467211 Valid MSE:0.7223232844296623                 Train MAE:0.659310023520933 Valid MAE:0.6664174485694417
# Epoch:4 Learning rate 5.623413251903491e-05 Weight Decay 1e-07 Train Loss:0.6985343026104792                 Valid Loss:0.7219276893169374 Train RMSE:0.8348069048127389 Valid RMSE:0.8487073022348341 Train MSE:0.6985343026104792 Valid MSE:0.7219276893169374                 Train MAE:0.6576931368806398 Valid MAE:0.6661331888354952
# Epoch:5 Learning rate 3.1622776601683795e-05 Weight Decay 1e-07 Train Loss:0.6975041038108069                 Valid Loss:0.7219114119134595 Train RMSE:0.8341315810694269 Valid RMSE:0.8485238714913351 Train MSE:0.6975041038108069 Valid MSE:0.7219114119134595                 Train MAE:0.6573319023123918 Valid MAE:0.6661495525208886
# Epoch:6 Learning rate 1.778279410038923e-05 Weight Decay 1e-07 Train Loss:0.6961704475621388                 Valid Loss:0.7217671028183549 Train RMSE:0.8333726835631371 Valid RMSE:0.8484735623504229 Train MSE:0.6961704475621388 Valid MSE:0.7217671028183549                 Train MAE:0.6566350989494942 Valid MAE:0.6660263236526334
# Epoch:7 Learning rate 1e-05 Weight Decay 1e-07 Train Loss:0.6950283166458568                 Valid Loss:0.7217723576309126 Train RMSE:0.8327027078452585 Valid RMSE:0.8484722675481596 Train MSE:0.6950283166458568 Valid MSE:0.7217723576309126                 Train MAE:0.6561905396469351 Valid MAE:0.6661195602563336
# Epoch:8 Learning rate 0.0001 Weight Decay 1e-07 Train Loss:0.6983499475626367                 Valid Loss:0.721948351396624 Train RMSE:0.8347049034757622 Valid RMSE:0.8484815004689444 Train MSE:0.6983499475626367 Valid MSE:0.721948351396624                 Train MAE:0.6579650177310263 Valid MAE:0.6664195963183938
# Epoch:9 Learning rate 7.498942093324559e-05 Weight Decay 1e-07 Train Loss:0.6959950805456082                 Valid Loss:0.721601111809616 Train RMSE:0.8332256949498212 Valid RMSE:0.8483681653853204 Train MSE:0.6959950805456082 Valid MSE:0.721601111809616                 Train MAE:0.6565504292889959 Valid MAE:0.6663061299592333
# Epoch:10 Learning rate 5.6234132519034914e-05 Weight Decay 1e-07 Train Loss:0.694441237155097                 Valid Loss:0.7215082677428984 Train RMSE:0.8323439483514198 Valid RMSE:0.8484072518087549 Train MSE:0.694441237155097 Valid MSE:0.7215082677428984                 Train MAE:0.6558472871915976 Valid MAE:0.6661043479619428
# Epoch:11 Learning rate 4.216965034285823e-05 Weight Decay 1e-07 Train Loss:0.6937518312929705                 Valid Loss:0.7215592034942354 Train RMSE:0.8319234714464394 Valid RMSE:0.8483489153080769 Train MSE:0.6937518312929705 Valid MSE:0.7215592034942354                 Train MAE:0.655425918841179 Valid MAE:0.6654704662844958
# Epoch:12 Learning rate 3.1622776601683795e-05 Weight Decay 1e-07 Train Loss:0.6927342646020971                 Valid Loss:0.7214508323413332 Train RMSE:0.8313324759672066 Valid RMSE:0.8482561466823897 Train MSE:0.6927342646020971 Valid MSE:0.7214508323413332                 Train MAE:0.6548367773974725 Valid MAE:0.6658157873946382
# Epoch:13 Learning rate 2.3713737056616557e-05 Weight Decay 1e-07 Train Loss:0.6932272230456897                 Valid Loss:0.7212718766363685 Train RMSE:0.8315821943750504 Valid RMSE:0.8482745870499482 Train MSE:0.6932272230456897 Valid MSE:0.7212718766363685                 Train MAE:0.6551131297317051 Valid MAE:0.6656104823207611
# Epoch:14 Learning rate 1.7782794100389232e-05 Weight Decay 1e-07 Train Loss:0.6914217855345975                 Valid Loss:0.7216060913127401 Train RMSE:0.8305741646660691 Valid RMSE:0.8484208438669913 Train MSE:0.6914217855345975 Valid MSE:0.7216060913127401                 Train MAE:0.6544394982549187 Valid MAE:0.6652592152280881

# %%
optimizer=torch.optim.Adam(cfobj.parameters(),lr=7e-4,betas=(0.9,0.999), weight_decay=wd)
learner=Learner(cfobj,optimizer,None,device,0,12000,0.25,cycle_mult=2,start_lr=7e-4,end_lr=7e-5)
learner.run_epochs(dltrain,dlvalid,15)
# Out:
# Epoch:0 Learning rate 0.0007 Weight Decay 1e-07 Train Loss:0.7154331968730235                 Valid Loss:0.7264226286307626 Train RMSE:0.8448487463156518 Valid RMSE:0.8512709455090661 Train MSE:0.7154331968730235 Valid MSE:0.7264226286307626                 Train MAE:0.6663580423971452 Valid MAE:0.668636038632649
# Epoch:1 Learning rate 0.00022135943621178655 Weight Decay 1e-07 Train Loss:0.699556844357167                 Valid Loss:0.7235983883023567 Train RMSE:0.835440803449067 Valid RMSE:0.8496411234627339 Train MSE:0.699556844357167 Valid MSE:0.7235983883023567                 Train MAE:0.658174287927127 Valid MAE:0.6674698240616742
# Epoch:2 Learning rate 7e-05 Weight Decay 1e-07 Train Loss:0.6923086758886239                 Valid Loss:0.7228384612466369 Train RMSE:0.8310682940958544 Valid RMSE:0.8490605448187263 Train MSE:0.6923086758886239 Valid MSE:0.7228384612466369                 Train MAE:0.6543868400001851 Valid MAE:0.6661795069799399
# Epoch:3 Learning rate 0.0007 Weight Decay 1e-07 Train Loss:0.7090808407366191                 Valid Loss:0.7255319766986096 Train RMSE:0.8410566234231073 Valid RMSE:0.8507209632335172 Train MSE:0.7090808407366191 Valid MSE:0.7255319766986096                 Train MAE:0.663246479755035 Valid MAE:0.6693955419008689
# Epoch:4 Learning rate 0.00039363892763324434 Weight Decay 1e-07 Train Loss:0.6972406512470045                 Valid Loss:0.7245745873817092 Train RMSE:0.8340474946420149 Valid RMSE:0.8501870855440707 Train MSE:0.6972406512470045 Valid MSE:0.7245745873817092                 Train MAE:0.6573683802363612 Valid MAE:0.666372213064862
# Epoch:5 Learning rate 0.00022135943621178655 Weight Decay 1e-07 Train Loss:0.6896801628204174                 Valid Loss:0.7229407598905246 Train RMSE:0.829501416300901 Valid RMSE:0.8491026966600675 Train MSE:0.6896801628204174 Valid MSE:0.7229407598905246                 Train MAE:0.6532570175193134 Valid MAE:0.6663828226916321
# Epoch:6 Learning rate 0.00012447955870272459 Weight Decay 1e-07 Train Loss:0.6838962422333762                 Valid Loss:0.7230007146935329 Train RMSE:0.8259563886092822 Valid RMSE:0.8491080690273698 Train MSE:0.6838962422333762 Valid MSE:0.7230007146935329                 Train MAE:0.6501253113036201 Valid MAE:0.6654328245031255
# Epoch:7 Learning rate 7e-05 Weight Decay 1e-07 Train Loss:0.6808074214918084                 Valid Loss:0.7231590854542335 Train RMSE:0.8240523344028746 Valid RMSE:0.8493785312075812 Train MSE:0.6808074214918084 Valid MSE:0.7231590854542335                 Train MAE:0.6483974664225509 Valid MAE:0.6655656152674
# Epoch:8 Learning rate 0.0007 Weight Decay 1e-07 Train Loss:0.6991657331259643                 Valid Loss:0.7257148038090953 Train RMSE:0.8351615181933203 Valid RMSE:0.8507763778025758 Train MSE:0.6991657331259643 Valid MSE:0.7257148038090953                 Train MAE:0.6580231304971339 Valid MAE:0.667928885011112
# Epoch:9 Learning rate 0.0005249259465327192 Weight Decay 1e-07 Train Loss:0.6932403087988813                 Valid Loss:0.724675193009779 Train RMSE:0.8315575093908445 Valid RMSE:0.8502765983248339 Train MSE:0.6932403087988813 Valid MSE:0.724675193009779                 Train MAE:0.654993809164333 Valid MAE:0.6675936291589761
# Epoch:10 Learning rate 0.00039363892763324444 Weight Decay 1e-07 Train Loss:0.6865488008185818                 Valid Loss:0.7250067270015512 Train RMSE:0.8275790473741942 Valid RMSE:0.8503130480632581 Train MSE:0.6865488008185818 Valid MSE:0.7250067270015512                 Train MAE:0.6515890281072285 Valid MAE:0.6680560322368846
# Epoch:11 Learning rate 0.00029518755240000766 Weight Decay 1e-07 Train Loss:0.6805938348652865                 Valid Loss:0.7242692022982156 Train RMSE:0.8239846852501701 Valid RMSE:0.8499417426548467 Train MSE:0.6805938348652865 Valid MSE:0.7242692022982156                 Train MAE:0.6483976644719904 Valid MAE:0.6659683691876014
# Epoch:12 Learning rate 0.00022135943621178663 Weight Decay 1e-07 Train Loss:0.6764125423333779                 Valid Loss:0.723676454075767 Train RMSE:0.8214442948196978 Valid RMSE:0.8497001662710999 Train MSE:0.6764125423333779 Valid MSE:0.723676454075767                 Train MAE:0.6460169783565921 Valid MAE:0.666121833007354
# Epoch:13 Learning rate 0.00016599615939631593 Weight Decay 1e-07 Train Loss:0.6733099123463564                 Valid Loss:0.7246849364636804 Train RMSE:0.8195470620126201 Valid RMSE:0.8500532494038708 Train MSE:0.6733099123463564 Valid MSE:0.7246849364636804                 Train MAE:0.6445547866319641 Valid MAE:0.6658369871356603
# Epoch:14 Learning rate 0.00012447955870272464 Weight Decay 1e-07 Train Loss:0.6725562942919489                 Valid Loss:0.7247030122200852 Train RMSE:0.819102934209727 Valid RMSE:0.8503058911088653 Train MSE:0.6725562942919489 Valid MSE:0.7247030122200852                 Train MAE:0.6439510745896444 Valid MAE:0.665412629504338

# %%
optimizer=torch.optim.Adam(cfobj.parameters(),lr=1e-4,betas=(0.9,0.999), weight_decay=wd)
learner=Learner(cfobj,optimizer,None,device,0,12000,0.25,cycle_mult=0)
learner.run_epochs(dltrain,dlvalid,5)
# Out:
# Epoch:0 Learning rate 0.0001 Weight Decay 1e-07 Train Loss:0.7074187639459887                 Valid Loss:0.7228477441746256 Train RMSE:0.8400949523353103 Valid RMSE:0.8491791857251103 Train MSE:0.7074187639459887 Valid MSE:0.7228477441746256                 Train MAE:0.6623956776831277 Valid MAE:0.667780279198571
# Epoch:1 Learning rate 0.0001 Weight Decay 1e-07 Train Loss:0.7058330476453503                 Valid Loss:0.7222061710589377 Train RMSE:0.8391305040726594 Valid RMSE:0.8488443251240779 Train MSE:0.7058330476453503 Valid MSE:0.7222061710589377                 Train MAE:0.661271692644238 Valid MAE:0.6666243591576891
# Epoch:2 Learning rate 0.0001 Weight Decay 1e-07 Train Loss:0.7056453650330562                 Valid Loss:0.7222626370084865 Train RMSE:0.8390569187870137 Valid RMSE:0.8487753466684725 Train MSE:0.7056453650330562 Valid MSE:0.7222626370084865                 Train MAE:0.6612435581333637 Valid MAE:0.6670784032558237
# Epoch:3 Learning rate 0.0001 Weight Decay 1e-07 Train Loss:0.704694349097365                 Valid Loss:0.7225008660265247 Train RMSE:0.8384136263305324 Valid RMSE:0.8490370086439206 Train MSE:0.704694349097365 Valid MSE:0.7225008660265247                 Train MAE:0.660526857682511 Valid MAE:0.666569751851699
# Epoch:4 Learning rate 0.0001 Weight Decay 1e-07 Train Loss:0.7029667193573715                 Valid Loss:0.7221172057149355 Train RMSE:0.8374541390565144 Valid RMSE:0.8488439156045398 Train MSE:0.7029667193573715 Valid MSE:0.7221172057149355                 Train MAE:0.6596202784076752 Valid MAE:0.6670226195584172

# %%
device
# Out:
# 'cuda:1'

# %%
torch.save(cfobj,f=f'{DATAPATH}/inter/cf_plus_tl_model')
torch.save(learner,f=f'{DATAPATH}/inter/cf_plus_tl_learner')
torch.save(optimizer,f=f'{DATAPATH}/inter/cf_plus_tl_optimizer')
torch.save(cfobj.state_dict(),f'{DATAPATH}/inter/cf_plus_tl_state_dict')
torch.save(optimizer.state_dict(),f'{DATAPATH}/inter/cf_plus_tl_optimizer_state_dict')
# Out:
# /home/kirana/anaconda3/lib/python3.7/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type cf. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/kirana/anaconda3/lib/python3.7/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type cf. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
df_train.head().T
# Out:
#                                                          0  \
# userId                                                3908
# itemId                                                2347
# rating                                                   4
# timestamp                                        965941231
# gender                                                   M
# age                                                     25
# occupation                                               0
# zip                                                  10021
# title                Pope of Greenwich Village, The (1984)
# genre                                               Action
# random_dstype                                        train
# user_idx                                                 1
# item_idx                                                 1
# dstype_random_train                                      1
# dstype_random_valid                                      0
# gender_idx                                               1
# age_idx                                                  1
# title_idx                                                1
# genre_idx                                                1
# zip_idx                                                  1
# item_autoenc0                                     -3.18609
# item_autoenc1                                      1.61987
# item_autoenc2                                     -4.62387
# item_autoenc3                                      1.61161
# item_autoenc4                                      6.89472
# item_autoenc5                                      2.89067
# item_autoenc6                                      3.65705
# item_autoenc7                                      3.94195
# item_autoenc8                                      4.00683
# item_autoenc9                                     -4.19065
# item_autoenc10                                     2.56122
# item_autoenc11                                      2.4966
# item_autoenc12                                    -4.77567
# item_autoenc13                                     4.06451
# item_autoenc14                                   -0.100498
# item_autoenc15                                     3.21852
# item_autoenc16                                     2.54616
# item_autoenc17                                   -0.447566
# item_autoenc18                                     3.71568
# item_autoenc19                                    0.373989
# item_autoenc20                                      -4.584
# item_autoenc21                                     2.35915
# item_autoenc22                                    -3.56623
# item_autoenc23                                    -6.40143
# item_autoenc24                                    -1.90849
# user_autoenc0                                     -1.69489
# user_autoenc1                                     -0.15193
# user_autoenc2                                      1.12497
# user_autoenc3                                     -1.84113
# user_autoenc4                                     -2.11238
# user_autoenc5                                     -1.08032
# user_autoenc6                                      1.37426
# user_autoenc7                                      -2.9095
# user_autoenc8                                    -0.340611
# user_autoenc9                                     -1.39775
#
#                                            1  \
# userId                                  1254
# itemId                                  1541
# rating                                     2
# timestamp                          974823280
# gender                                     F
# age                                       18
# occupation                                 1
# zip                                    02144
# title                Addicted to Love (1997)
# genre                         Comedy|Romance
# random_dstype                          train
# user_idx                                   2
# item_idx                                   2
# dstype_random_train                        1
# dstype_random_valid                        0
# gender_idx                                 2
# age_idx                                    2
# title_idx                                  2
# genre_idx                                  2
# zip_idx                                    2
# item_autoenc0                      -0.421671
# item_autoenc1                       -1.74049
# item_autoenc2                       0.700414
# item_autoenc3                        1.22237
# item_autoenc4                        5.43473
# item_autoenc5                        2.58028
# item_autoenc6                      -0.305813
# item_autoenc7                        4.30003
# item_autoenc8                        2.11304
# item_autoenc9                       -3.04318
# item_autoenc10                       3.77746
# item_autoenc11                     -0.526732
# item_autoenc12                      -2.76207
# item_autoenc13                        3.2549
# item_autoenc14                       3.44448
# item_autoenc15                      -2.05392
# item_autoenc16                       1.02707
# item_autoenc17                     -0.588286
# item_autoenc18                      0.455141
# item_autoenc19                     -0.415664
# item_autoenc20                      -1.45349
# item_autoenc21                       5.35785
# item_autoenc22                      0.752502
# item_autoenc23                      -3.57229
# item_autoenc24                      -4.16374
# user_autoenc0                       0.807896
# user_autoenc1                       -1.37693
# user_autoenc2                       0.162299
# user_autoenc3                      0.0800919
# user_autoenc4                       0.537038
# user_autoenc5                        0.58596
# user_autoenc6                      -0.161436
# user_autoenc7                        1.04845
# user_autoenc8                       -1.03584
# user_autoenc9                      -0.490745
#
#                                                     2  \
# userId                                           1467
# itemId                                           2617
# rating                                              3
# timestamp                                   977173059
# gender                                              M
# age                                                25
# occupation                                          5
# zip                                             97007
# title                               Mummy, The (1999)
# genre                Action|Adventure|Horror|Thriller
# random_dstype                                   train
# user_idx                                            3
# item_idx                                            3
# dstype_random_train                                 1
# dstype_random_valid                                 0
# gender_idx                                          1
# age_idx                                             1
# title_idx                                           3
# genre_idx                                           3
# zip_idx                                             3
# item_autoenc0                                -3.64614
# item_autoenc1                                 4.01921
# item_autoenc2                                -4.61749
# item_autoenc3                                 3.03887
# item_autoenc4                                 5.00175
# item_autoenc5                                 5.42459
# item_autoenc6                                 5.72009
# item_autoenc7                                 4.58495
# item_autoenc8                                 4.14181
# item_autoenc9                                -1.75184
# item_autoenc10                                2.74367
# item_autoenc11                                4.30917
# item_autoenc12                               -4.66519
# item_autoenc13                                5.11113
# item_autoenc14                              -0.139202
# item_autoenc15                                 3.8554
# item_autoenc16                                2.92381
# item_autoenc17                            -0.00864169
# item_autoenc18                                5.08992
# item_autoenc19                                4.33009
# item_autoenc20                               -3.42062
# item_autoenc21                                2.16932
# item_autoenc22                               -2.20661
# item_autoenc23                               -3.33078
# item_autoenc24                               -0.62895
# user_autoenc0                               -0.736317
# user_autoenc1                               -0.517018
# user_autoenc2                                 1.21311
# user_autoenc3                                -1.96156
# user_autoenc4                                -1.42359
# user_autoenc5                                -1.06577
# user_autoenc6                                0.938449
# user_autoenc7                                -1.57077
# user_autoenc8                               -0.542528
# user_autoenc9                                -1.75681
#
#                                                                   3  \
# userId                                                         4717
# itemId                                                         3754
# rating                                                            3
# timestamp                                                 963502544
# gender                                                            M
# age                                                              45
# occupation                                                       17
# zip                                                           48310
# title                Adventures of Rocky and Bullwinkle, The (2000)
# genre                                   Animation|Children's|Comedy
# random_dstype                                                 train
# user_idx                                                          4
# item_idx                                                          4
# dstype_random_train                                               1
# dstype_random_valid                                               0
# gender_idx                                                        1
# age_idx                                                           3
# title_idx                                                         4
# genre_idx                                                         4
# zip_idx                                                           4
# item_autoenc0                                             -0.253813
# item_autoenc1                                               1.82171
# item_autoenc2                                            -0.0798218
# item_autoenc3                                               5.65835
# item_autoenc4                                               -4.5117
# item_autoenc5                                              -1.91984
# item_autoenc6                                             -0.854778
# item_autoenc7                                              -1.48345
# item_autoenc8                                              -8.07635
# item_autoenc9                                               3.43065
# item_autoenc10                                             -3.14474
# item_autoenc11                                            -0.323866
# item_autoenc12                                              3.51864
# item_autoenc13                                             -3.57655
# item_autoenc14                                             -1.54887
# item_autoenc15                                             -2.53546
# item_autoenc16                                             -3.82195
# item_autoenc17                                             -4.01713
# item_autoenc18                                             -1.79514
# item_autoenc19                                            -0.851271
# item_autoenc20                                              4.18969
# item_autoenc21                                             -4.01747
# item_autoenc22                                             0.367825
# item_autoenc23                                              4.76462
# item_autoenc24                                             0.370236
# user_autoenc0                                              -1.39915
# user_autoenc1                                              0.328619
# user_autoenc2                                              -1.66596
# user_autoenc3                                              -1.06243
# user_autoenc4                                             -0.760788
# user_autoenc5                                              0.939962
# user_autoenc6                                              -1.31154
# user_autoenc7                                             -0.389501
# user_autoenc8                                               0.41406
# user_autoenc9                                            -0.0956787
#
#                                                4
# userId                                      1789
# itemId                                      2997
# rating                                         5
# timestamp                              974700402
# gender                                         M
# age                                            1
# occupation                                    10
# zip                                        19116
# title                Being John Malkovich (1999)
# genre                                     Comedy
# random_dstype                              train
# user_idx                                       5
# item_idx                                       5
# dstype_random_train                            1
# dstype_random_valid                            0
# gender_idx                                     1
# age_idx                                        4
# title_idx                                      5
# genre_idx                                      5
# zip_idx                                        5
# item_autoenc0                             1.2718
# item_autoenc1                           -1.23279
# item_autoenc2                            2.15573
# item_autoenc3                           0.708601
# item_autoenc4                            2.94528
# item_autoenc5                           0.331645
# item_autoenc6                           -1.82178
# item_autoenc7                            1.43738
# item_autoenc8                           -1.90595
# item_autoenc9                           -1.63002
# item_autoenc10                           1.66402
# item_autoenc11                          -1.14657
# item_autoenc12                         -0.886866
# item_autoenc13                          0.573695
# item_autoenc14                           4.08154
# item_autoenc15                          -2.11624
# item_autoenc16                          -2.24355
# item_autoenc17                          -1.78868
# item_autoenc18                           -1.7201
# item_autoenc19                          -1.40734
# item_autoenc20                           1.01285
# item_autoenc21                           3.78471
# item_autoenc22                           2.57459
# item_autoenc23                          -2.10167
# item_autoenc24                           -3.7227
# user_autoenc0                           0.432887
# user_autoenc1                         -0.0560655
# user_autoenc2                           0.165773
# user_autoenc3                           0.295746
# user_autoenc4                           0.357427
# user_autoenc5                           0.560581
# user_autoenc6                          0.0506818
# user_autoenc7                           -1.07002
# user_autoenc8                            0.19762
# user_autoenc9                           0.240095

# %%
learner=Learner(cfobj,optimizer,None,device,0,12000,0.25,cycle_mult=2,start_lr=4e-4,end_lr=4e-5)

# %%
learner.run_epochs(dltrain,dlvalid,5)
# Out:
# Epoch:0 Learning rate 0.0004 Weight Decay 1e-07 Train Loss:0.7085841895971904                 Valid Loss:0.7400470947289406 Train RMSE:0.8397724017164323 Valid RMSE:0.85807563937078 Train MSE:0.7085841895971904 Valid MSE:0.7400470947289406                 Train MAE:0.6619035640600885 Valid MAE:0.6723562184806979
# Epoch:1 Learning rate 0.00012649110640673518 Weight Decay 1e-07 Train Loss:0.6798945998765829                 Valid Loss:0.7379258986934066 Train RMSE:0.8225438637391805 Valid RMSE:0.8568596157406778 Train MSE:0.6798945998765829 Valid MSE:0.7379258986934066                 Train MAE:0.6468499570504439 Valid MAE:0.6719082392695005
# Epoch:2 Learning rate 4e-05 Weight Decay 1e-07 Train Loss:0.6643356711125791                 Valid Loss:0.7378187339629054 Train RMSE:0.8130279397105312 Valid RMSE:0.8566577295047599 Train MSE:0.6643356711125791 Valid MSE:0.7378187339629054                 Train MAE:0.6387030012438414 Valid MAE:0.6708499585728511
# Epoch:3 Learning rate 0.0004 Weight Decay 1e-07 Train Loss:0.690994669927331                 Valid Loss:0.7409031232223486 Train RMSE:0.8291969627977501 Valid RMSE:0.8582699536144381 Train MSE:0.690994669927331 Valid MSE:0.7409031232223486                 Train MAE:0.6523215139927505 Valid MAE:0.6728887881159478
# Epoch:4 Learning rate 0.00022493653007613963 Weight Decay 1e-07 Train Loss:0.6719820732694423                 Valid Loss:0.7395882790198411 Train RMSE:0.8177432900226704 Valid RMSE:0.8578646890461471 Train MSE:0.6719820732694423 Valid MSE:0.7395882790198411                 Train MAE:0.6426145539766149 Valid MAE:0.6719660262012725

# %%
torch.save(cfobj,f=f'{DATAPATH}/inter/cf_plus_tl_model')
torch.save(learner,f=f'{DATAPATH}/inter/cf_plus_tl_learner')
torch.save(optimizer,f=f'{DATAPATH}/inter/cf_plus_tl_optimizer')
torch.save(cfobj.state_dict(),f'{DATAPATH}/inter/cf_plus_tl_state_dict')
torch.save(optimizer.state_dict(),f'{DATAPATH}/inter/cf_plus_tl_optimizer_state_dict')
# Out:
# /home/kirana/anaconda3/lib/python3.7/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type cf. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/kirana/anaconda3/lib/python3.7/site-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type cf. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
learner=Learner(cfobj,optimizer,None,device,0,12000,0.25,cycle_mult=2,start_lr=5e-4,end_lr=5e-5)

# %%
learner.run_epochs(dltrain,dlvalid,6)
# Out:
# Epoch:0 Learning rate 0.0005 Weight Decay 1e-07 Train Loss:0.6941850676096538                 Valid Loss:0.7433338718646018 Train RMSE:0.8311313092989665 Valid RMSE:0.8599301569925202 Train MSE:0.6941850676096538 Valid MSE:0.7433338718646018                 Train MAE:0.654575018786645 Valid MAE:0.6774439708808498
# Epoch:1 Learning rate 0.00015811388300841897 Weight Decay 1e-07 Train Loss:0.6689964935329719                 Valid Loss:0.7434683173056453 Train RMSE:0.8158519026145334 Valid RMSE:0.8600390302833822 Train MSE:0.6689964935329719 Valid MSE:0.7434683173056453                 Train MAE:0.6416919659952952 Valid MAE:0.6729949602233175
# Epoch:2 Learning rate 5e-05 Weight Decay 1e-07 Train Loss:0.6554071987512592                 Valid Loss:0.7456495886492303 Train RMSE:0.8075521838911383 Valid RMSE:0.8610663575701407 Train MSE:0.6554071987512592 Valid MSE:0.7456495886492303                 Train MAE:0.6345673236181806 Valid MAE:0.6730673684336036
# Epoch:3 Learning rate 0.0005 Weight Decay 1e-07 Train Loss:0.6817611748516585                 Valid Loss:0.7447651546934376 Train RMSE:0.8236157621166844 Valid RMSE:0.8607553626491721 Train MSE:0.6817611748516585 Valid MSE:0.7447651546934376                 Train MAE:0.6480848270121601 Valid MAE:0.6755552239277783
# Epoch:4 Learning rate 0.00028117066259517455 Weight Decay 1e-07 Train Loss:0.665836791950321                 Valid Loss:0.7441837996854197 Train RMSE:0.8139341219661479 Valid RMSE:0.8603160831777734 Train MSE:0.665836791950321 Valid MSE:0.7441837996854197                 Train MAE:0.6398085501274343 Valid MAE:0.6738998514154683
# Epoch:5 Learning rate 0.00015811388300841897 Weight Decay 1e-07 Train Loss:0.6518914396954721                 Valid Loss:0.7463562851747894 Train RMSE:0.8053656980508187 Valid RMSE:0.8615527861889123 Train MSE:0.6518914396954721 Valid MSE:0.7463562851747894                 Train MAE:0.6322417607665757 Valid MAE:0.6730665390753685
